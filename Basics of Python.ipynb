# %% [markdown]
# # Python Basics

# %% [markdown]
# #### Print

# %%
a=4
print('Hello\n World')
print(f'Number is {a} ')
print(r'Hello \' world')  #r will eradicate the effect of escape Sequences
# Out:
# Hello
#  World
# Number is 4
# Hello \' world

# %% [markdown]
# #### Commands

# %%
# pip install packege
# python 
# python --version
# python file.py
# python -m pip install –upgrade pip
# pwd 
# exit

# %% [markdown]
# #### Variables

# %%
name,age,salary,male='abdul',   35,   5000.67   , True
print(name+str(age))                        # Concatenation 
type(name)                                  # check type of Data Types
type(range(0,10))                           # range is another data type but you can iterate over it
                                       # Range -> integer Sequence   
x=y=z= 10
x,y,z = 12,22,44
# Out:
# abdul35

# %% [markdown]
# ### Random No.s

# %%
import random as rd
rd.seed(34)
num=rd.randint(0,100)      #specific for integers 
nums=rd.randrange(0,100)   #not specific for Integers only

# %%
num
# Out:
# 67

# %% [markdown]
# #### Strings

# %%
import string
a='Hello World'
b='Hello,World'
a+'How are you'   # concatenation 
a[3:6]            # Upto Six
"World" in a      # in operator 
"World" not in a  # Negation of in
### SOME FUNCTIONS
a.upper()
a.lower()

a.replace('Hello','Fitta Munn')


a.strip()
x1,x2=b.split(',')     #Return a List
a.find('ello')
# Out:
# 1

# %%
st = "aabccb"
st=list(st)
"".join(st)
# Out:
# 'aabccb'

# %% [markdown]
# ### List

# %%
nums=['a',2,4,'Rehman',44.56]  # Hetrogeneous list
nums[2:-1]
nums[0:len(nums):2]          # slicing and Stepping
### Functions 
list({4,3,4,5,3,2,4});list(range(0,10))     # convert set tuples and iteratable in list
nums.append(34)                # add on the top     (Postional)
nums.pop()                     # remove from the end(Postional)
nums.insert(2,2333)            # Pos and Value      (Postional)
nums.remove(2333)              # remove by           (name)
# nums.clear()                 # clear the list
del(nums[0])                   # Remove from index
num2=nums.copy()               #create a copy

# %% [markdown]
# ### Tuples

# %%
mytuple=(2,3,4,5,5,2,5)
mytuple[0:-4]
if 3 in mytuple:
    print('Ay Dunya pittal di')
tup1=(1,2)
tup2=('Malok Ji','Raja Ji')
tup3=tup1+tup2
tup3
# Out:
# Ay Dunya pittal di
# (1, 2, 'Malok Ji', 'Raja Ji')

# %% [markdown]
# ### Sets

# %%
set1={2,3,4,21,4,12,4}   # Set do not have Definite Indexing, 
set2={45,2,45,23,4,2,5}
fset=frozenset(set1)        #Immutable brothers of set 
### Almost every functions of List applicable on Sets aswell
set1.union(set2)           #Union of set
set1.intersection(set2)    #Intersaection 
set1.difference(set2)
# Out:
# {3, 12, 21}

# %%
fset
# Out:
# frozenset({2, 3, 4, 12, 21})

# %% [markdown]
# ### Dictionaries

# %%
customer={'name': "Abdul Rehman",      #keys must be unique, concrete and can't be cahnged 
         'pass':12345,
         1234:'user Id ',
         'actions':['order','withdrawn','paid']}  
customer['name']
customer[1234]
customer['actions'][0]
customer['years']=1234                           #it will overwrite or create the a new value
### FUNCTIONS
### Mostly List functions will work 
cars=dict(brand="Ford",id=1234,speed="123kp/h")  #Have look Keenly
customer.get('activities',"No activity")         # if not found default will be placed 
customer.keys()
customer.values()
customer.items()
for i in customer:
    print(i)
customer.pop('name')
del(customer['pass'])
# Out:
# name
# pass
# 1234
# actions
# years

# %% [markdown]
# ### Nested Dictionaries

# %%
employe={
    'clerk':{
        'id':1234,
        'salary':34524
    },
    'boss':{
        'id':4321,
        'salary':lambda a:a+2
    }
}
employe['boss']['salary'](4)
# Out:
# 6

# %% [markdown]
# ### Elif , if and Else

# %%
a=3
b='name'
if a==3 and "n" in b:
    print("welcome")      # Indention
elif not (a==3 ) or len(b)==1:
    print('Daffa')
else:
    print("BHai araha ha ")
# Out:
# welcome

# %% [markdown]
# ### Loops

# %%
i=2
while i!=5:
    print(i)   # continue and break can be used
    i=i+1
for i in range(1,10):
    print("Hi There")
# Out:
# 2
# 3
# 4
# Hi There
# Hi There
# Hi There
# Hi There
# Hi There
# Hi There
# Hi There
# Hi There
# Hi There

# %% [markdown]
# ### Functions
# #### arbitrary arguments and Keyworded arguments

# %%
# *args
def sumall(*nums):           # accepts tuple of Multiple argument
    sum=0
    for i in nums:
        sum=sum+i
    return sum
sumall(2,3,4,5,6,6,7,8,8)
# **kwargs
def multiply(**nums):       # accept a dictionary of multiple argument
    a=nums.keys()
    product=1
    for i in a:
        product=nums[i]*product
        
        
    return product
multiply(x=3,y=4,z=6)
### RETURN PACKING and unPacking return (sum,product)
# Out:
# 72

# %% [markdown]
# ### LAMBADAS

# %%
sum1=lambda a,b,c:a+b+c # anynomus Functions
sum1(2,3,4)
def anynomus(num):
    return lambda  : num*123423 
a=anynomus(2)
print(a())
# Out:
# 246846

# %% [markdown]
# ### Modules

# %%
### CREATE A MODULE
# ANY FILE SAVED WITH .py EXTENSION CAN BE CALLED AND USED IN YOUR PROGRAME
### IMPORT 
import numpy as np
# import ppp as p
# from ppp import sqaure         your own .py file 
# ppp.sqaure(2)
dir(np)                      #will give all accessible functions
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__doc__',
#  '__file__',
#  '__git_revision__',
#  '__loader__',
#  '__mkl_version__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_add_newdoc_ufunc',
#  '_arg',
#  '_distributor_init',
#  '_globals',
#  '_mat',
#  '_mklinit',
#  '_pytesttester',
#  'abs',
#  'absolute',
#  'absolute_import',
#  'add',
#  'add_docstring',
#  'add_newdoc',
#  'add_newdoc_ufunc',
#  'alen',
#  'all',
#  'allclose',
#  'alltrue',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
#  'arctan',
#  'arctan2',
#  'arctanh',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'argwhere',
#  'around',
#  'array',
#  'array2string',
#  'array_equal',
#  'array_equiv',
#  'array_repr',
#  'array_split',
#  'array_str',
#  'asanyarray',
#  'asarray',
#  'asarray_chkfinite',
#  'ascontiguousarray',
#  'asfarray',
#  'asfortranarray',
#  'asmatrix',
#  'asscalar',
#  'atleast_1d',
#  'atleast_2d',
#  'atleast_3d',
#  'average',
#  'bartlett',
#  'base_repr',
#  'binary_repr',
#  'bincount',
#  'bitwise_and',
#  'bitwise_not',
#  'bitwise_or',
#  'bitwise_xor',
#  'blackman',
#  'block',
#  'bmat',
#  'bool',
#  'bool8',
#  'bool_',
#  'broadcast',
#  'broadcast_arrays',
#  'broadcast_to',
#  'busday_count',
#  'busday_offset',
#  'busdaycalendar',
#  'byte',
#  'byte_bounds',
#  'bytes0',
#  'bytes_',
#  'c_',
#  'can_cast',
#  'cast',
#  'cbrt',
#  'cdouble',
#  'ceil',
#  'cfloat',
#  'char',
#  'character',
#  'chararray',
#  'choose',
#  'clip',
#  'clongdouble',
#  'clongfloat',
#  'column_stack',
#  'common_type',
#  'compare_chararrays',
#  'compat',
#  'complex',
#  'complex128',
#  'complex64',
#  'complex_',
#  'complexfloating',
#  'compress',
#  'concatenate',
#  'conj',
#  'conjugate',
#  'convolve',
#  'copy',
#  'copysign',
#  'copyto',
#  'core',
#  'corrcoef',
#  'correlate',
#  'cos',
#  'cosh',
#  'count_nonzero',
#  'cov',
#  'cross',
#  'csingle',
#  'ctypeslib',
#  'cumprod',
#  'cumproduct',
#  'cumsum',
#  'datetime64',
#  'datetime_as_string',
#  'datetime_data',
#  'deg2rad',
#  'degrees',
#  'delete',
#  'deprecate',
#  'deprecate_with_doc',
#  'diag',
#  'diag_indices',
#  'diag_indices_from',
#  'diagflat',
#  'diagonal',
#  'diff',
#  'digitize',
#  'disp',
#  'divide',
#  'division',
#  'divmod',
#  'dot',
#  'double',
#  'dsplit',
#  'dstack',
#  'dtype',
#  'e',
#  'ediff1d',
#  'einsum',
#  'einsum_path',
#  'emath',
#  'empty',
#  'empty_like',
#  'equal',
#  'errstate',
#  'euler_gamma',
#  'exp',
#  'exp2',
#  'expand_dims',
#  'expm1',
#  'extract',
#  'eye',
#  'fabs',
#  'fastCopyAndTranspose',
#  'fft',
#  'fill_diagonal',
#  'find_common_type',
#  'finfo',
#  'fix',
#  'flatiter',
#  'flatnonzero',
#  'flexible',
#  'flip',
#  'fliplr',
#  'flipud',
#  'float',
#  'float16',
#  'float32',
#  'float64',
#  'float_',
#  'float_power',
#  'floating',
#  'floor',
#  'floor_divide',
#  'fmax',
#  'fmin',
#  'fmod',
#  'format_float_positional',
#  'format_float_scientific',
#  'format_parser',
#  'frexp',
#  'frombuffer',
#  'fromfile',
#  'fromfunction',
#  'fromiter',
#  'frompyfunc',
#  'fromregex',
#  'fromstring',
#  'full',
#  'full_like',
#  'fv',
#  'gcd',
#  'generic',
#  'genfromtxt',
#  'geomspace',
#  'get_array_wrap',
#  'get_include',
#  'get_printoptions',
#  'getbufsize',
#  'geterr',
#  'geterrcall',
#  'geterrobj',
#  'gradient',
#  'greater',
#  'greater_equal',
#  'half',
#  'hamming',
#  'hanning',
#  'heaviside',
#  'histogram',
#  'histogram2d',
#  'histogram_bin_edges',
#  'histogramdd',
#  'hsplit',
#  'hstack',
#  'hypot',
#  'i0',
#  'identity',
#  'iinfo',
#  'imag',
#  'in1d',
#  'index_exp',
#  'indices',
#  'inexact',
#  'inf',
#  'info',
#  'infty',
#  'inner',
#  'insert',
#  'int',
#  'int0',
#  'int16',
#  'int32',
#  'int64',
#  'int8',
#  'int_',
#  'int_asbuffer',
#  'intc',
#  'integer',
#  'interp',
#  'intersect1d',
#  'intp',
#  'invert',
#  'ipmt',
#  'irr',
#  'is_busday',
#  'isclose',
#  'iscomplex',
#  'iscomplexobj',
#  'isfinite',
#  'isfortran',
#  'isin',
#  'isinf',
#  'isnan',
#  'isnat',
#  'isneginf',
#  'isposinf',
#  'isreal',
#  'isrealobj',
#  'isscalar',
#  'issctype',
#  'issubclass_',
#  'issubdtype',
#  'issubsctype',
#  'iterable',
#  'ix_',
#  'kaiser',
#  'kron',
#  'lcm',
#  'ldexp',
#  'left_shift',
#  'less',
#  'less_equal',
#  'lexsort',
#  'lib',
#  'linalg',
#  'linspace',
#  'little_endian',
#  'load',
#  'loads',
#  'loadtxt',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'logaddexp',
#  'logaddexp2',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'logical_xor',
#  'logspace',
#  'long',
#  'longcomplex',
#  'longdouble',
#  'longfloat',
#  'longlong',
#  'lookfor',
#  'ma',
#  'mafromtxt',
#  'mask_indices',
#  'mat',
#  'math',
#  'matmul',
#  'matrix',
#  'matrixlib',
#  'max',
#  'maximum',
#  'maximum_sctype',
#  'may_share_memory',
#  'mean',
#  'median',
#  'memmap',
#  'meshgrid',
#  'mgrid',
#  'min',
#  'min_scalar_type',
#  'minimum',
#  'mintypecode',
#  'mirr',
#  'mod',
#  'modf',
#  'moveaxis',
#  'msort',
#  'multiply',
#  'nan',
#  'nan_to_num',
#  'nanargmax',
#  'nanargmin',
#  'nancumprod',
#  'nancumsum',
#  'nanmax',
#  'nanmean',
#  'nanmedian',
#  'nanmin',
#  'nanpercentile',
#  'nanprod',
#  'nanquantile',
#  'nanstd',
#  'nansum',
#  'nanvar',
#  'nbytes',
#  'ndarray',
#  'ndenumerate',
#  'ndfromtxt',
#  'ndim',
#  'ndindex',
#  'nditer',
#  'negative',
#  'nested_iters',
#  'newaxis',
#  'nextafter',
#  'nonzero',
#  'not_equal',
#  'nper',
#  'npv',
#  'numarray',
#  'number',
#  'obj2sctype',
#  'object',
#  'object0',
#  'object_',
#  'ogrid',
#  'oldnumeric',
#  'ones',
#  'ones_like',
#  'outer',
#  'packbits',
#  'pad',
#  'partition',
#  'percentile',
#  'pi',
#  'piecewise',
#  'place',
#  'pmt',
#  'poly',
#  'poly1d',
#  'polyadd',
#  'polyder',
#  'polydiv',
#  'polyfit',
#  'polyint',
#  'polymul',
#  'polynomial',
#  'polysub',
#  'polyval',
#  'positive',
#  'power',
#  'ppmt',
#  'print_function',
#  'printoptions',
#  'prod',
#  'product',
#  'promote_types',
#  'ptp',
#  'put',
#  'put_along_axis',
#  'putmask',
#  'pv',
#  'quantile',
#  'r_',
#  'rad2deg',
#  'radians',
#  'random',
#  'rank',
#  'rate',
#  'ravel',
#  'ravel_multi_index',
#  'real',
#  'real_if_close',
#  'rec',
#  'recarray',
#  'recfromcsv',
#  'recfromtxt',
#  'reciprocal',
#  'record',
#  'remainder',
#  'repeat',
#  'require',
#  'reshape',
#  'resize',
#  'result_type',
#  'right_shift',
#  'rint',
#  'roll',
#  'rollaxis',
#  'roots',
#  'rot90',
#  'round',
#  'round_',
#  'row_stack',
#  's_',
#  'safe_eval',
#  'save',
#  'savetxt',
#  'savez',
#  'savez_compressed',
#  'sctype2char',
#  'sctypeDict',
#  'sctypeNA',
#  'sctypes',
#  'searchsorted',
#  'select',
#  'set_numeric_ops',
#  'set_printoptions',
#  'set_string_function',
#  'setbufsize',
#  'setdiff1d',
#  'seterr',
#  'seterrcall',
#  'seterrobj',
#  'setxor1d',
#  'shape',
#  'shares_memory',
#  'short',
#  'show_config',
#  'sign',
#  'signbit',
#  'signedinteger',
#  'sin',
#  'sinc',
#  'single',
#  'singlecomplex',
#  'sinh',
#  'size',
#  'sometrue',
#  'sort',
#  'sort_complex',
#  'source',
#  'spacing',
#  'split',
#  'sqrt',
#  'square',
#  'squeeze',
#  'stack',
#  'std',
#  'str',
#  'str0',
#  'str_',
#  'string_',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'sys',
#  'take',
#  'take_along_axis',
#  'tan',
#  'tanh',
#  'tensordot',
#  'test',
#  'testing',
#  'tile',
#  'timedelta64',
#  'trace',
#  'tracemalloc_domain',
#  'transpose',
#  'trapz',
#  'tri',
#  'tril',
#  'tril_indices',
#  'tril_indices_from',
#  'trim_zeros',
#  'triu',
#  'triu_indices',
#  'triu_indices_from',
#  'true_divide',
#  'trunc',
#  'typeDict',
#  'typeNA',
#  'typecodes',
#  'typename',
#  'ubyte',
#  'ufunc',
#  'uint',
#  'uint0',
#  'uint16',
#  'uint32',
#  'uint64',
#  'uint8',
#  'uintc',
#  'uintp',
#  'ulonglong',
#  'unicode',
#  'unicode_',
#  'union1d',
#  'unique',
#  'unpackbits',
#  'unravel_index',
#  'unsignedinteger',
#  'unwrap',
#  'ushort',
#  'vander',
#  'var',
#  'vdot',
#  'vectorize',
#  'version',
#  'void',
#  'void0',
#  'vsplit',
#  'vstack',
#  'warnings',
#  'where',
#  'who',
#  'zeros',
#  'zeros_like']

# %% [markdown]
# ### DataTime Incompelete

# %%
import datetime as dt
x=dt.datetime.now()
y = dt.datetime(2020 , 5 , 17).strftime("%B %y ")
x.strftime("%H")             #formatting the Date Time

# x.year                     # calling atribute without ()
#dir(dt)                    #Will give you all accessible objects and functions of the module
# Out:
# '16'

# %% [markdown]
# ### JSON

# %%
### Data Might Be Excel , CSV , JSON 
import json
data1='{"custname":"Abdul","Id":1234,"Type":"Permanent"}' #This is our data 
data2="[1,2,3,4,5]"
data3="(2,3,4,556)"
###PARSING JSON into data
parsed1=json.loads(data1)       #Load Function for Parsing
parsed1['custname']
parsed2=json.loads(data2)
parsed2[0]
### Converting Data Into JSON
a=[2,3,4,5,5]
dic1={'name':"Abdul","Id":1234}
json.dumps(dic1)                #dumps for conversion
# Out:
# '{"name": "Abdul", "Id": 1234}'

# %% [markdown]
# ### Regular Exp

# %%
import re
paraghraph="If You cannot do great If Things Do small things in a great Way"
re.search("[a-f]",paraghraph)
# re.search("things$",paraghraph)
# re.findall("[s-v]",paraghraph)
# Out:
# <re.Match object; span=(1, 2), match='f'>

# %% [markdown]
# https://www.w3schools.com/python/python_regex.asp

# %% [markdown]
# ## READING FILES

# %%
import os
files=[]
path=r'D:/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files'
for dirpath,subdirectories,filenames in os.walk(path): # os.walk will go to the Path and will determine whats are the file , whats the dir and root 
    for filename in filenames:                         # File path containing our months data
        files.append(filename)
print("\n All the Files we have\n")
for pos,data in enumerate(files):
    print(pos+1,data)

# OR
# Out:
#  All the Files we have
#
# 1 101_1b1_Al_sc_Meditron.txt
# 2 101_1b1_Al_sc_Meditron.wav
# 3 101_1b1_Pr_sc_Meditron.txt
# 4 101_1b1_Pr_sc_Meditron.wav
# 5 102_1b1_Ar_sc_Meditron.txt
# 6 102_1b1_Ar_sc_Meditron.wav
# 7 103_2b2_Ar_mc_LittC2SE.txt
# 8 103_2b2_Ar_mc_LittC2SE.wav
# 9 104_1b1_Al_sc_Litt3200.txt
# 10 104_1b1_Al_sc_Litt3200.wav
# 11 104_1b1_Ar_sc_Litt3200.txt
# 12 104_1b1_Ar_sc_Litt3200.wav
# 13 104_1b1_Ll_sc_Litt3200.txt
# 14 104_1b1_Ll_sc_Litt3200.wav
# 15 104_1b1_Lr_sc_Litt3200.txt
# 16 104_1b1_Lr_sc_Litt3200.wav
# 17 104_1b1_Pl_sc_Litt3200.txt
# 18 104_1b1_Pl_sc_Litt3200.wav
# 19 104_1b1_Pr_sc_Litt3200.txt
# 20 104_1b1_Pr_sc_Litt3200.wav
# 21 105_1b1_Tc_sc_Meditron.txt
# 22 105_1b1_Tc_sc_Meditron.wav
# 23 106_2b1_Pl_mc_LittC2SE.txt
# 24 106_2b1_Pl_mc_LittC2SE.wav
# 25 106_2b1_Pr_mc_LittC2SE.txt
# 26 106_2b1_Pr_mc_LittC2SE.wav
# 27 107_2b3_Al_mc_AKGC417L.txt
# 28 107_2b3_Al_mc_AKGC417L.wav
# 29 107_2b3_Ar_mc_AKGC417L.txt
# 30 107_2b3_Ar_mc_AKGC417L.wav
# 31 107_2b3_Ll_mc_AKGC417L.txt
# 32 107_2b3_Ll_mc_AKGC417L.wav
# 33 107_2b3_Lr_mc_AKGC417L.txt
# 34 107_2b3_Lr_mc_AKGC417L.wav
# 35 107_2b3_Pl_mc_AKGC417L.txt
# 36 107_2b3_Pl_mc_AKGC417L.wav
# 37 107_2b3_Pr_mc_AKGC417L.txt
# 38 107_2b3_Pr_mc_AKGC417L.wav
# 39 107_2b3_Tc_mc_AKGC417L.txt
# 40 107_2b3_Tc_mc_AKGC417L.wav
# 41 107_2b4_Al_mc_AKGC417L.txt
# 42 107_2b4_Al_mc_AKGC417L.wav
# 43 107_2b4_Ar_mc_AKGC417L.txt
# 44 107_2b4_Ar_mc_AKGC417L.wav
# 45 107_2b4_Ll_mc_AKGC417L.txt
# 46 107_2b4_Ll_mc_AKGC417L.wav
# 47 107_2b4_Lr_mc_AKGC417L.txt
# 48 107_2b4_Lr_mc_AKGC417L.wav
# 49 107_2b4_Pl_mc_AKGC417L.txt
# 50 107_2b4_Pl_mc_AKGC417L.wav
# 51 107_2b4_Pr_mc_AKGC417L.txt
# 52 107_2b4_Pr_mc_AKGC417L.wav
# 53 107_2b4_Tc_mc_AKGC417L.txt
# 54 107_2b4_Tc_mc_AKGC417L.wav
# 55 107_2b5_Al_mc_AKGC417L.txt
# 56 107_2b5_Al_mc_AKGC417L.wav
# 57 107_2b5_Ar_mc_AKGC417L.txt
# 58 107_2b5_Ar_mc_AKGC417L.wav
# 59 107_2b5_Ll_mc_AKGC417L.txt
# 60 107_2b5_Ll_mc_AKGC417L.wav
# 61 107_2b5_Lr_mc_AKGC417L.txt
# 62 107_2b5_Lr_mc_AKGC417L.wav
# 63 107_2b5_Pl_mc_AKGC417L.txt
# 64 107_2b5_Pl_mc_AKGC417L.wav
# 65 107_2b5_Pr_mc_AKGC417L.txt
# 66 107_2b5_Pr_mc_AKGC417L.wav
# 67 107_2b5_Tc_mc_AKGC417L.txt
# 68 107_2b5_Tc_mc_AKGC417L.wav
# 69 107_3p2_Al_mc_AKGC417L.txt
# 70 107_3p2_Al_mc_AKGC417L.wav
# 71 107_3p2_Ar_mc_AKGC417L.txt
# 72 107_3p2_Ar_mc_AKGC417L.wav
# 73 107_3p2_Ll_mc_AKGC417L.txt
# 74 107_3p2_Ll_mc_AKGC417L.wav
# 75 107_3p2_Lr_mc_AKGC417L.txt
# 76 107_3p2_Lr_mc_AKGC417L.wav
# 77 107_3p2_Pl_mc_AKGC417L.txt
# 78 107_3p2_Pl_mc_AKGC417L.wav
# 79 107_3p2_Pr_mc_AKGC417L.txt
# 80 107_3p2_Pr_mc_AKGC417L.wav
# 81 107_3p2_Tc_mc_AKGC417L.txt
# 82 107_3p2_Tc_mc_AKGC417L.wav
# 83 108_1b1_Al_sc_Meditron.txt
# 84 108_1b1_Al_sc_Meditron.wav
# 85 109_1b1_Al_sc_Litt3200.txt
# 86 109_1b1_Al_sc_Litt3200.wav
# 87 109_1b1_Ar_sc_Litt3200.txt
# 88 109_1b1_Ar_sc_Litt3200.wav
# 89 109_1b1_Ll_sc_Litt3200.txt
# 90 109_1b1_Ll_sc_Litt3200.wav
# 91 109_1b1_Lr_sc_Litt3200.txt
# 92 109_1b1_Lr_sc_Litt3200.wav
# 93 109_1b1_Pl_sc_Litt3200.txt
# 94 109_1b1_Pl_sc_Litt3200.wav
# 95 109_1b1_Pr_sc_Litt3200.txt
# 96 109_1b1_Pr_sc_Litt3200.wav
# 97 110_1b1_Pr_sc_Meditron.txt
# 98 110_1b1_Pr_sc_Meditron.wav
# 99 110_1p1_Al_sc_Meditron.txt
# 100 110_1p1_Al_sc_Meditron.wav
# 101 110_1p1_Ll_sc_Meditron.txt
# 102 110_1p1_Ll_sc_Meditron.wav
# 103 110_1p1_Lr_sc_Meditron.txt
# 104 110_1p1_Lr_sc_Meditron.wav
# 105 110_1p1_Pr_sc_Meditron.txt
# 106 110_1p1_Pr_sc_Meditron.wav
# 107 111_1b2_Tc_sc_Meditron.txt
# 108 111_1b2_Tc_sc_Meditron.wav
# 109 111_1b3_Tc_sc_Meditron.txt
# 110 111_1b3_Tc_sc_Meditron.wav
# 111 112_1b1_Ar_sc_Meditron.txt
# 112 112_1b1_Ar_sc_Meditron.wav
# 113 112_1b1_Lr_sc_Meditron.txt
# 114 112_1b1_Lr_sc_Meditron.wav
# 115 112_1p1_Ll_sc_Litt3200.txt
# 116 112_1p1_Ll_sc_Litt3200.wav
# 117 112_1p1_Pl_sc_Litt3200.txt
# 118 112_1p1_Pl_sc_Litt3200.wav
# 119 112_1p1_Pr_sc_Litt3200.txt
# 120 112_1p1_Pr_sc_Litt3200.wav
# 121 113_1b1_Al_sc_Litt3200.txt
# 122 113_1b1_Al_sc_Litt3200.wav
# 123 113_1b1_Ar_sc_Litt3200.txt
# 124 113_1b1_Ar_sc_Litt3200.wav
# 125 113_1b1_Ll_sc_Litt3200.txt
# 126 113_1b1_Ll_sc_Litt3200.wav
# 127 113_1b1_Lr_sc_Litt3200.txt
# 128 113_1b1_Lr_sc_Litt3200.wav
# 129 113_1b1_Pl_sc_Litt3200.txt
# 130 113_1b1_Pl_sc_Litt3200.wav
# 131 113_1b1_Pr_sc_Litt3200.txt
# 132 113_1b1_Pr_sc_Litt3200.wav
# 133 114_1b4_Al_mc_AKGC417L.txt
# 134 114_1b4_Al_mc_AKGC417L.wav
# 135 114_1b4_Ar_mc_AKGC417L.txt
# 136 114_1b4_Ar_mc_AKGC417L.wav
# 137 114_1b4_Lr_mc_AKGC417L.txt
# 138 114_1b4_Lr_mc_AKGC417L.wav
# 139 114_1b4_Pl_mc_AKGC417L.txt
# 140 114_1b4_Pl_mc_AKGC417L.wav
# 141 114_1b4_Pr_mc_AKGC417L.txt
# 142 114_1b4_Pr_mc_AKGC417L.wav
# 143 115_1b1_Ar_sc_Meditron.txt
# 144 115_1b1_Ar_sc_Meditron.wav
# 145 116_1b2_Pl_sc_Meditron.txt
# 146 116_1b2_Pl_sc_Meditron.wav
# 147 116_1b2_Tc_sc_Meditron.txt
# 148 116_1b2_Tc_sc_Meditron.wav
# 149 117_1b2_Tc_mc_LittC2SE.txt
# 150 117_1b2_Tc_mc_LittC2SE.wav
# 151 117_1b3_Tc_mc_LittC2SE.txt
# 152 117_1b3_Tc_mc_LittC2SE.wav
# 153 118_1b1_Al_sc_Litt3200.txt
# 154 118_1b1_Al_sc_Litt3200.wav
# 155 118_1b1_Ar_sc_Litt3200.txt
# 156 118_1b1_Ar_sc_Litt3200.wav
# 157 118_1b1_Ll_sc_Litt3200.txt
# 158 118_1b1_Ll_sc_Litt3200.wav
# 159 118_1b1_Lr_sc_Litt3200.txt
# 160 118_1b1_Lr_sc_Litt3200.wav
# 161 118_1b1_Pl_sc_Litt3200.txt
# 162 118_1b1_Pl_sc_Litt3200.wav
# 163 118_1b1_Pr_sc_Litt3200.txt
# 164 118_1b1_Pr_sc_Litt3200.wav
# 165 119_1b1_Ar_sc_Meditron.txt
# 166 119_1b1_Ar_sc_Meditron.wav
# 167 120_1b1_Al_sc_Meditron.txt
# 168 120_1b1_Al_sc_Meditron.wav
# 169 120_1b1_Ar_sc_Meditron.txt
# 170 120_1b1_Ar_sc_Meditron.wav
# 171 120_1b1_Lr_sc_Meditron.txt
# 172 120_1b1_Lr_sc_Meditron.wav
# 173 120_1b1_Pl_sc_Meditron.txt
# 174 120_1b1_Pl_sc_Meditron.wav
# 175 120_1b1_Pr_sc_Meditron.txt
# 176 120_1b1_Pr_sc_Meditron.wav
# 177 121_1b1_Tc_sc_Meditron.txt
# 178 121_1b1_Tc_sc_Meditron.wav
# 179 121_1p1_Tc_sc_Meditron.txt
# 180 121_1p1_Tc_sc_Meditron.wav
# 181 122_2b1_Al_mc_LittC2SE.txt
# 182 122_2b1_Al_mc_LittC2SE.wav
# 183 122_2b1_Ar_mc_LittC2SE.txt
# 184 122_2b1_Ar_mc_LittC2SE.wav
# 185 122_2b1_Tc_mc_LittC2SE.txt
# 186 122_2b1_Tc_mc_LittC2SE.wav
# 187 122_2b2_Al_mc_LittC2SE.txt
# 188 122_2b2_Al_mc_LittC2SE.wav
# 189 122_2b2_Ar_mc_LittC2SE.txt
# 190 122_2b2_Ar_mc_LittC2SE.wav
# 191 122_2b2_Tc_mc_LittC2SE.txt
# 192 122_2b2_Tc_mc_LittC2SE.wav
# 193 122_2b3_Al_mc_LittC2SE.txt
# 194 122_2b3_Al_mc_LittC2SE.wav
# 195 122_2b3_Ar_mc_LittC2SE.txt
# 196 122_2b3_Ar_mc_LittC2SE.wav
# 197 122_2b3_Tc_mc_LittC2SE.txt
# 198 122_2b3_Tc_mc_LittC2SE.wav
# 199 123_1b1_Al_sc_Meditron.txt
# 200 123_1b1_Al_sc_Meditron.wav
# 201 124_1b1_Al_sc_Litt3200.txt
# 202 124_1b1_Al_sc_Litt3200.wav
# 203 124_1b1_Ar_sc_Litt3200.txt
# 204 124_1b1_Ar_sc_Litt3200.wav
# 205 124_1b1_Ll_sc_Litt3200.txt
# 206 124_1b1_Ll_sc_Litt3200.wav
# 207 124_1b1_Lr_sc_Litt3200.txt
# 208 124_1b1_Lr_sc_Litt3200.wav
# 209 124_1b1_Pl_sc_Litt3200.txt
# 210 124_1b1_Pl_sc_Litt3200.wav
# 211 124_1b1_Pr_sc_Litt3200.txt
# 212 124_1b1_Pr_sc_Litt3200.wav
# 213 125_1b1_Tc_sc_Meditron.txt
# 214 125_1b1_Tc_sc_Meditron.wav
# 215 126_1b1_Al_sc_Meditron.txt
# 216 126_1b1_Al_sc_Meditron.wav
# 217 127_1b1_Ar_sc_Meditron.txt
# 218 127_1b1_Ar_sc_Meditron.wav
# 219 128_1b3_Tc_mc_LittC2SE.txt
# 220 128_1b3_Tc_mc_LittC2SE.wav
# 221 129_1b1_Ar_sc_Meditron.txt
# 222 129_1b1_Ar_sc_Meditron.wav
# 223 130_1p2_Al_mc_AKGC417L.txt
# 224 130_1p2_Al_mc_AKGC417L.wav
# 225 130_1p2_Ar_mc_AKGC417L.txt
# 226 130_1p2_Ar_mc_AKGC417L.wav
# 227 130_1p2_Ll_mc_AKGC417L.txt
# 228 130_1p2_Ll_mc_AKGC417L.wav
# 229 130_1p2_Lr_mc_AKGC417L.txt
# 230 130_1p2_Lr_mc_AKGC417L.wav
# 231 130_1p2_Pl_mc_AKGC417L.txt
# 232 130_1p2_Pl_mc_AKGC417L.wav
# 233 130_1p2_Pr_mc_AKGC417L.txt
# 234 130_1p2_Pr_mc_AKGC417L.wav
# 235 130_1p2_Tc_mc_AKGC417L.txt
# 236 130_1p2_Tc_mc_AKGC417L.wav
# 237 130_1p3_Al_mc_AKGC417L.txt
# 238 130_1p3_Al_mc_AKGC417L.wav
# 239 130_1p3_Ar_mc_AKGC417L.txt
# 240 130_1p3_Ar_mc_AKGC417L.wav
# 241 130_1p3_Ll_mc_AKGC417L.txt
# 242 130_1p3_Ll_mc_AKGC417L.wav
# 243 130_1p3_Lr_mc_AKGC417L.txt
# 244 130_1p3_Lr_mc_AKGC417L.wav
# 245 130_1p3_Pl_mc_AKGC417L.txt
# 246 130_1p3_Pl_mc_AKGC417L.wav
# 247 130_1p3_Pr_mc_AKGC417L.txt
# 248 130_1p3_Pr_mc_AKGC417L.wav
# 249 130_1p3_Tc_mc_AKGC417L.txt
# 250 130_1p3_Tc_mc_AKGC417L.wav
# 251 130_1p4_Al_mc_AKGC417L.txt
# 252 130_1p4_Al_mc_AKGC417L.wav
# 253 130_1p4_Ar_mc_AKGC417L.txt
# 254 130_1p4_Ar_mc_AKGC417L.wav
# 255 130_1p4_Ll_mc_AKGC417L.txt
# 256 130_1p4_Ll_mc_AKGC417L.wav
# 257 130_1p4_Lr_mc_AKGC417L.txt
# 258 130_1p4_Lr_mc_AKGC417L.wav
# 259 130_1p4_Pl_mc_AKGC417L.txt
# 260 130_1p4_Pl_mc_AKGC417L.wav
# 261 130_1p4_Pr_mc_AKGC417L.txt
# 262 130_1p4_Pr_mc_AKGC417L.wav
# 263 130_1p4_Tc_mc_AKGC417L.txt
# 264 130_1p4_Tc_mc_AKGC417L.wav
# 265 130_2b2_Al_mc_AKGC417L.txt
# 266 130_2b2_Al_mc_AKGC417L.wav
# 267 130_2b2_Ar_mc_AKGC417L.txt
# 268 130_2b2_Ar_mc_AKGC417L.wav
# 269 130_2b2_Ll_mc_AKGC417L.txt
# 270 130_2b2_Ll_mc_AKGC417L.wav
# 271 130_2b2_Lr_mc_AKGC417L.txt
# 272 130_2b2_Lr_mc_AKGC417L.wav
# 273 130_2b2_Pl_mc_AKGC417L.txt
# 274 130_2b2_Pl_mc_AKGC417L.wav
# 275 130_2b2_Pr_mc_AKGC417L.txt
# 276 130_2b2_Pr_mc_AKGC417L.wav
# 277 130_2b2_Tc_mc_AKGC417L.txt
# 278 130_2b2_Tc_mc_AKGC417L.wav
# 279 130_2b3_Al_mc_AKGC417L.txt
# 280 130_2b3_Al_mc_AKGC417L.wav
# 281 130_2b3_Ar_mc_AKGC417L.txt
# 282 130_2b3_Ar_mc_AKGC417L.wav
# 283 130_2b3_Ll_mc_AKGC417L.txt
# 284 130_2b3_Ll_mc_AKGC417L.wav
# 285 130_2b3_Lr_mc_AKGC417L.txt
# 286 130_2b3_Lr_mc_AKGC417L.wav
# 287 130_2b3_Pl_mc_AKGC417L.txt
# 288 130_2b3_Pl_mc_AKGC417L.wav
# 289 130_2b3_Pr_mc_AKGC417L.txt
# 290 130_2b3_Pr_mc_AKGC417L.wav
# 291 130_2b3_Tc_mc_AKGC417L.txt
# 292 130_2b3_Tc_mc_AKGC417L.wav
# 293 130_2b4_Al_mc_AKGC417L.txt
# 294 130_2b4_Al_mc_AKGC417L.wav
# 295 130_2b4_Ar_mc_AKGC417L.txt
# 296 130_2b4_Ar_mc_AKGC417L.wav
# 297 130_2b4_Ll_mc_AKGC417L.txt
# 298 130_2b4_Ll_mc_AKGC417L.wav
# 299 130_2b4_Lr_mc_AKGC417L.txt
# 300 130_2b4_Lr_mc_AKGC417L.wav
# 301 130_2b4_Pl_mc_AKGC417L.txt
# 302 130_2b4_Pl_mc_AKGC417L.wav
# 303 130_2p3_Pl_mc_AKGC417L.txt
# 304 130_2p3_Pl_mc_AKGC417L.wav
# 305 130_2p5_Al_mc_AKGC417L.txt
# 306 130_2p5_Al_mc_AKGC417L.wav
# 307 130_2p5_Ar_mc_AKGC417L.txt
# 308 130_2p5_Ar_mc_AKGC417L.wav
# 309 130_2p5_Lr_mc_AKGC417L.txt
# 310 130_2p5_Lr_mc_AKGC417L.wav
# 311 130_2p5_Pl_mc_AKGC417L.txt
# 312 130_2p5_Pl_mc_AKGC417L.wav
# 313 130_2p5_Pr_mc_AKGC417L.txt
# 314 130_2p5_Pr_mc_AKGC417L.wav
# 315 130_2p5_Tc_mc_AKGC417L.txt
# 316 130_2p5_Tc_mc_AKGC417L.wav
# 317 130_3b3_Ll_mc_AKGC417L.txt
# 318 130_3b3_Ll_mc_AKGC417L.wav
# 319 130_3b4_Al_mc_AKGC417L.txt
# 320 130_3b4_Al_mc_AKGC417L.wav
# 321 130_3b4_Ar_mc_AKGC417L.txt
# 322 130_3b4_Ar_mc_AKGC417L.wav
# 323 130_3b4_Lr_mc_AKGC417L.txt
# 324 130_3b4_Lr_mc_AKGC417L.wav
# 325 130_3b4_Pl_mc_AKGC417L.txt
# 326 130_3b4_Pl_mc_AKGC417L.wav
# 327 130_3b4_Pr_mc_AKGC417L.txt
# 328 130_3b4_Pr_mc_AKGC417L.wav
# 329 130_3p2_Al_mc_AKGC417L.txt
# 330 130_3p2_Al_mc_AKGC417L.wav
# 331 130_3p2_Ar_mc_AKGC417L.txt
# 332 130_3p2_Ar_mc_AKGC417L.wav
# 333 130_3p2_Pl_mc_AKGC417L.txt
# 334 130_3p2_Pl_mc_AKGC417L.wav
# 335 130_3p2_Pr_mc_AKGC417L.txt
# 336 130_3p2_Pr_mc_AKGC417L.wav
# 337 130_3p2_Tc_mc_AKGC417L.txt
# 338 130_3p2_Tc_mc_AKGC417L.wav
# 339 130_3p3_Al_mc_AKGC417L.txt
# 340 130_3p3_Al_mc_AKGC417L.wav
# 341 130_3p3_Pl_mc_AKGC417L.txt
# 342 130_3p3_Pl_mc_AKGC417L.wav
# 343 130_3p3_Pr_mc_AKGC417L.txt
# 344 130_3p3_Pr_mc_AKGC417L.wav
# 345 130_3p3_Tc_mc_AKGC417L.txt
# 346 130_3p3_Tc_mc_AKGC417L.wav
# 347 130_3p4_Al_mc_AKGC417L.txt
# 348 130_3p4_Al_mc_AKGC417L.wav
# 349 130_3p4_Pl_mc_AKGC417L.txt
# 350 130_3p4_Pl_mc_AKGC417L.wav
# 351 130_3p4_Pr_mc_AKGC417L.txt
# 352 130_3p4_Pr_mc_AKGC417L.wav
# 353 130_3p4_Tc_mc_AKGC417L.txt
# 354 130_3p4_Tc_mc_AKGC417L.wav
# 355 131_1b1_Al_sc_Meditron.txt
# 356 131_1b1_Al_sc_Meditron.wav
# 357 132_2b1_Lr_mc_LittC2SE.txt
# 358 132_2b1_Lr_mc_LittC2SE.wav
# 359 132_2b2_Lr_mc_LittC2SE.txt
# 360 132_2b2_Lr_mc_LittC2SE.wav
# 361 133_2p2_Al_mc_AKGC417L.txt
# 362 133_2p2_Al_mc_AKGC417L.wav
# 363 133_2p2_Ar_mc_AKGC417L.txt
# 364 133_2p2_Ar_mc_AKGC417L.wav
# 365 133_2p2_Pl_mc_AKGC417L.txt
# 366 133_2p2_Pl_mc_AKGC417L.wav
# 367 133_2p2_Tc_mc_AKGC417L.txt
# 368 133_2p2_Tc_mc_AKGC417L.wav
# 369 133_2p3_Al_mc_AKGC417L.txt
# 370 133_2p3_Al_mc_AKGC417L.wav
# 371 133_2p3_Ar_mc_AKGC417L.txt
# 372 133_2p3_Ar_mc_AKGC417L.wav
# 373 133_2p3_Pl_mc_AKGC417L.txt
# 374 133_2p3_Pl_mc_AKGC417L.wav
# 375 133_2p3_Pr_mc_AKGC417L.txt
# 376 133_2p3_Pr_mc_AKGC417L.wav
# 377 133_2p3_Tc_mc_AKGC417L.txt
# 378 133_2p3_Tc_mc_AKGC417L.wav
# 379 133_2p4_Al_mc_AKGC417L.txt
# 380 133_2p4_Al_mc_AKGC417L.wav
# 381 133_2p4_Ar_mc_AKGC417L.txt
# 382 133_2p4_Ar_mc_AKGC417L.wav
# 383 133_2p4_Pl_mc_AKGC417L.txt
# 384 133_2p4_Pl_mc_AKGC417L.wav
# 385 133_2p4_Pr_mc_AKGC417L.txt
# 386 133_2p4_Pr_mc_AKGC417L.wav
# 387 133_2p4_Tc_mc_AKGC417L.txt
# 388 133_2p4_Tc_mc_AKGC417L.wav
# 389 133_3p2_Al_mc_AKGC417L.txt
# 390 133_3p2_Al_mc_AKGC417L.wav
# 391 133_3p2_Ar_mc_AKGC417L.txt
# 392 133_3p2_Ar_mc_AKGC417L.wav
# 393 133_3p2_Pl_mc_AKGC417L.txt
# 394 133_3p2_Pl_mc_AKGC417L.wav
# 395 133_3p2_Pr_mc_AKGC417L.txt
# 396 133_3p2_Pr_mc_AKGC417L.wav
# 397 133_3p4_Tc_mc_AKGC417L.txt
# 398 133_3p4_Tc_mc_AKGC417L.wav
# 399 134_2b1_Al_mc_LittC2SE.txt
# 400 134_2b1_Al_mc_LittC2SE.wav
# 401 134_2b1_Ar_mc_LittC2SE.txt
# 402 134_2b1_Ar_mc_LittC2SE.wav
# 403 134_2b2_Al_mc_LittC2SE.txt
# 404 134_2b2_Al_mc_LittC2SE.wav
# 405 134_2b2_Ar_mc_LittC2SE.txt
# 406 134_2b2_Ar_mc_LittC2SE.wav
# 407 134_2b3_Ar_mc_LittC2SE.txt
# 408 134_2b3_Ar_mc_LittC2SE.wav
# 409 135_2b1_Al_mc_LittC2SE.txt
# 410 135_2b1_Al_mc_LittC2SE.wav
# 411 135_2b1_Ar_mc_LittC2SE.txt
# 412 135_2b1_Ar_mc_LittC2SE.wav
# 413 135_2b1_Pl_mc_LittC2SE.txt
# 414 135_2b1_Pl_mc_LittC2SE.wav
# 415 135_2b1_Tc_mc_LittC2SE.txt
# 416 135_2b1_Tc_mc_LittC2SE.wav
# 417 135_2b2_Al_mc_LittC2SE.txt
# 418 135_2b2_Al_mc_LittC2SE.wav
# 419 135_2b2_Ar_mc_LittC2SE.txt
# 420 135_2b2_Ar_mc_LittC2SE.wav
# 421 135_2b2_Pl_mc_LittC2SE.txt
# 422 135_2b2_Pl_mc_LittC2SE.wav
# 423 135_2b2_Tc_mc_LittC2SE.txt
# 424 135_2b2_Tc_mc_LittC2SE.wav
# 425 135_2b3_Al_mc_LittC2SE.txt
# 426 135_2b3_Al_mc_LittC2SE.wav
# 427 135_2b3_Ar_mc_LittC2SE.txt
# 428 135_2b3_Ar_mc_LittC2SE.wav
# 429 135_2b3_Pl_mc_LittC2SE.txt
# 430 135_2b3_Pl_mc_LittC2SE.wav
# 431 135_2b3_Pr_mc_LittC2SE.txt
# 432 135_2b3_Pr_mc_LittC2SE.wav
# 433 135_2b3_Tc_mc_LittC2SE.txt
# 434 135_2b3_Tc_mc_LittC2SE.wav
# 435 136_1b1_Ar_sc_Meditron.txt
# 436 136_1b1_Ar_sc_Meditron.wav
# 437 137_1b1_Ar_sc_Meditron.txt
# 438 137_1b1_Ar_sc_Meditron.wav
# 439 137_1b1_Ll_sc_Meditron.txt
# 440 137_1b1_Ll_sc_Meditron.wav
# 441 138_1p2_Al_mc_AKGC417L.txt
# 442 138_1p2_Al_mc_AKGC417L.wav
# 443 138_1p2_Ar_mc_AKGC417L.txt
# 444 138_1p2_Ar_mc_AKGC417L.wav
# 445 138_1p2_Ll_mc_AKGC417L.txt
# 446 138_1p2_Ll_mc_AKGC417L.wav
# 447 138_1p2_Lr_mc_AKGC417L.txt
# 448 138_1p2_Lr_mc_AKGC417L.wav
# 449 138_1p2_Pl_mc_AKGC417L.txt
# 450 138_1p2_Pl_mc_AKGC417L.wav
# 451 138_1p2_Pr_mc_AKGC417L.txt
# 452 138_1p2_Pr_mc_AKGC417L.wav
# 453 138_1p2_Tc_mc_AKGC417L.txt
# 454 138_1p2_Tc_mc_AKGC417L.wav
# 455 138_1p3_Al_mc_AKGC417L.txt
# 456 138_1p3_Al_mc_AKGC417L.wav
# 457 138_1p3_Ar_mc_AKGC417L.txt
# 458 138_1p3_Ar_mc_AKGC417L.wav
# 459 138_1p3_Ll_mc_AKGC417L.txt
# 460 138_1p3_Ll_mc_AKGC417L.wav
# 461 138_1p3_Lr_mc_AKGC417L.txt
# 462 138_1p3_Lr_mc_AKGC417L.wav
# 463 138_1p3_Pl_mc_AKGC417L.txt
# 464 138_1p3_Pl_mc_AKGC417L.wav
# 465 138_1p3_Pr_mc_AKGC417L.txt
# 466 138_1p3_Pr_mc_AKGC417L.wav
# 467 138_1p3_Tc_mc_AKGC417L.txt
# 468 138_1p3_Tc_mc_AKGC417L.wav
# 469 138_1p4_Ar_mc_AKGC417L.txt
# 470 138_1p4_Ar_mc_AKGC417L.wav
# 471 138_1p4_Ll_mc_AKGC417L.txt
# 472 138_1p4_Ll_mc_AKGC417L.wav
# 473 138_1p4_Lr_mc_AKGC417L.txt
# 474 138_1p4_Lr_mc_AKGC417L.wav
# 475 138_1p4_Pl_mc_AKGC417L.txt
# 476 138_1p4_Pl_mc_AKGC417L.wav
# 477 138_1p4_Pr_mc_AKGC417L.txt
# 478 138_1p4_Pr_mc_AKGC417L.wav
# 479 138_1p4_Tc_mc_AKGC417L.txt
# 480 138_1p4_Tc_mc_AKGC417L.wav
# 481 138_2p2_Al_mc_AKGC417L.txt
# 482 138_2p2_Al_mc_AKGC417L.wav
# 483 138_2p2_Ar_mc_AKGC417L.txt
# 484 138_2p2_Ar_mc_AKGC417L.wav
# 485 138_2p2_Ll_mc_AKGC417L.txt
# 486 138_2p2_Ll_mc_AKGC417L.wav
# 487 138_2p2_Lr_mc_AKGC417L.txt
# 488 138_2p2_Lr_mc_AKGC417L.wav
# 489 138_2p2_Pl_mc_AKGC417L.txt
# 490 138_2p2_Pl_mc_AKGC417L.wav
# 491 138_2p2_Pr_mc_AKGC417L.txt
# 492 138_2p2_Pr_mc_AKGC417L.wav
# 493 138_2p2_Tc_mc_AKGC417L.txt
# 494 138_2p2_Tc_mc_AKGC417L.wav
# 495 139_1b1_Al_sc_Litt3200.txt
# 496 139_1b1_Al_sc_Litt3200.wav
# 497 139_1b1_Ar_sc_Litt3200.txt
# 498 139_1b1_Ar_sc_Litt3200.wav
# 499 139_1b1_Ll_sc_Litt3200.txt
# 500 139_1b1_Ll_sc_Litt3200.wav
# 501 139_1b1_Lr_sc_Litt3200.txt
# 502 139_1b1_Lr_sc_Litt3200.wav
# 503 139_1b1_Pl_sc_Litt3200.txt
# 504 139_1b1_Pl_sc_Litt3200.wav
# 505 139_1b1_Pr_sc_Litt3200.txt
# 506 139_1b1_Pr_sc_Litt3200.wav
# 507 140_2b2_Ll_mc_LittC2SE.txt
# 508 140_2b2_Ll_mc_LittC2SE.wav
# 509 140_2b2_Tc_mc_LittC2SE.txt
# 510 140_2b2_Tc_mc_LittC2SE.wav
# 511 140_2b3_Ll_mc_LittC2SE.txt
# 512 140_2b3_Ll_mc_LittC2SE.wav
# 513 140_2b3_Tc_mc_LittC2SE.txt
# 514 140_2b3_Tc_mc_LittC2SE.wav
# 515 141_1b1_Pr_mc_LittC2SE.txt
# 516 141_1b1_Pr_mc_LittC2SE.wav
# 517 141_1b2_Ar_mc_LittC2SE.txt
# 518 141_1b2_Ar_mc_LittC2SE.wav
# 519 141_1b2_Lr_mc_LittC2SE.txt
# 520 141_1b2_Lr_mc_LittC2SE.wav
# 521 141_1b2_Pr_mc_LittC2SE.txt
# 522 141_1b2_Pr_mc_LittC2SE.wav
# 523 141_1b2_Tc_mc_LittC2SE.txt
# 524 141_1b2_Tc_mc_LittC2SE.wav
# 525 141_1b3_Al_mc_LittC2SE.txt
# 526 141_1b3_Al_mc_LittC2SE.wav
# 527 141_1b3_Ar_mc_LittC2SE.txt
# 528 141_1b3_Ar_mc_LittC2SE.wav
# 529 141_1b3_Pr_mc_LittC2SE.txt
# 530 141_1b3_Pr_mc_LittC2SE.wav
# 531 142_1b1_Pl_mc_LittC2SE.txt
# 532 142_1b1_Pl_mc_LittC2SE.wav
# 533 143_1b1_Al_sc_Meditron.txt
# 534 143_1b1_Al_sc_Meditron.wav
# 535 144_1b1_Al_sc_Meditron.txt
# 536 144_1b1_Al_sc_Meditron.wav
# 537 144_1b1_Tc_sc_Meditron.txt
# 538 144_1b1_Tc_sc_Meditron.wav
# 539 145_2b2_Al_mc_AKGC417L.txt
# 540 145_2b2_Al_mc_AKGC417L.wav
# 541 145_2b2_Ar_mc_AKGC417L.txt
# 542 145_2b2_Ar_mc_AKGC417L.wav
# 543 145_2b2_Lr_mc_AKGC417L.txt
# 544 145_2b2_Lr_mc_AKGC417L.wav
# 545 145_2b2_Pr_mc_AKGC417L.txt
# 546 145_2b2_Pr_mc_AKGC417L.wav
# 547 145_3b2_Ar_mc_AKGC417L.txt
# 548 145_3b2_Ar_mc_AKGC417L.wav
# 549 145_3b2_Lr_mc_AKGC417L.txt
# 550 145_3b2_Lr_mc_AKGC417L.wav
# 551 145_3b4_Pl_mc_AKGC417L.txt
# 552 145_3b4_Pl_mc_AKGC417L.wav
# 553 146_2b2_Pl_mc_AKGC417L.txt
# 554 146_2b2_Pl_mc_AKGC417L.wav
# 555 146_2b4_Al_mc_AKGC417L.txt
# 556 146_2b4_Al_mc_AKGC417L.wav
# 557 146_2b4_Ar_mc_AKGC417L.txt
# 558 146_2b4_Ar_mc_AKGC417L.wav
# 559 146_2b4_Ll_mc_AKGC417L.txt
# 560 146_2b4_Ll_mc_AKGC417L.wav
# 561 146_2b4_Lr_mc_AKGC417L.txt
# 562 146_2b4_Lr_mc_AKGC417L.wav
# 563 146_2b4_Pr_mc_AKGC417L.txt
# 564 146_2b4_Pr_mc_AKGC417L.wav
# 565 146_8p3_Al_mc_AKGC417L.txt
# 566 146_8p3_Al_mc_AKGC417L.wav
# 567 146_8p3_Ar_mc_AKGC417L.txt
# 568 146_8p3_Ar_mc_AKGC417L.wav
# 569 146_8p3_Lr_mc_AKGC417L.txt
# 570 146_8p3_Lr_mc_AKGC417L.wav
# 571 146_8p3_Pl_mc_AKGC417L.txt
# 572 146_8p3_Pl_mc_AKGC417L.wav
# 573 146_8p3_Pr_mc_AKGC417L.txt
# 574 146_8p3_Pr_mc_AKGC417L.wav
# 575 147_1b2_Tc_mc_AKGC417L.txt
# 576 147_1b2_Tc_mc_AKGC417L.wav
# 577 147_1b3_Tc_mc_AKGC417L.txt
# 578 147_1b3_Tc_mc_AKGC417L.wav
# 579 147_1b4_Tc_mc_AKGC417L.txt
# 580 147_1b4_Tc_mc_AKGC417L.wav
# 581 147_2b2_Al_mc_AKGC417L.txt
# 582 147_2b2_Al_mc_AKGC417L.wav
# 583 147_2b2_Ar_mc_AKGC417L.txt
# 584 147_2b2_Ar_mc_AKGC417L.wav
# 585 147_2b2_Pl_mc_AKGC417L.txt
# 586 147_2b2_Pl_mc_AKGC417L.wav
# 587 147_2b3_Al_mc_AKGC417L.txt
# 588 147_2b3_Al_mc_AKGC417L.wav
# 589 147_2b3_Ar_mc_AKGC417L.txt
# 590 147_2b3_Ar_mc_AKGC417L.wav
# 591 147_2b3_Ll_mc_AKGC417L.txt
# 592 147_2b3_Ll_mc_AKGC417L.wav
# 593 147_2b3_Lr_mc_AKGC417L.txt
# 594 147_2b3_Lr_mc_AKGC417L.wav
# 595 147_2b3_Pl_mc_AKGC417L.txt
# 596 147_2b3_Pl_mc_AKGC417L.wav
# 597 147_2b4_Al_mc_AKGC417L.txt
# 598 147_2b4_Al_mc_AKGC417L.wav
# 599 147_2b4_Ar_mc_AKGC417L.txt
# 600 147_2b4_Ar_mc_AKGC417L.wav
# 601 147_2b4_Ll_mc_AKGC417L.txt
# 602 147_2b4_Ll_mc_AKGC417L.wav
# 603 147_2b4_Lr_mc_AKGC417L.txt
# 604 147_2b4_Lr_mc_AKGC417L.wav
# 605 147_2b4_Pl_mc_AKGC417L.txt
# 606 147_2b4_Pl_mc_AKGC417L.wav
# 607 148_1b1_Al_sc_Meditron.txt
# 608 148_1b1_Al_sc_Meditron.wav
# 609 149_1b1_Al_sc_Meditron.txt
# 610 149_1b1_Al_sc_Meditron.wav
# 611 149_1b1_Lr_sc_Meditron.txt
# 612 149_1b1_Lr_sc_Meditron.wav
# 613 149_1b1_Pl_sc_Meditron.txt
# 614 149_1b1_Pl_sc_Meditron.wav
# 615 150_1b2_Al_sc_Meditron.txt
# 616 150_1b2_Al_sc_Meditron.wav
# 617 151_2p2_Al_mc_AKGC417L.txt
# 618 151_2p2_Al_mc_AKGC417L.wav
# 619 151_2p2_Ar_mc_AKGC417L.txt
# 620 151_2p2_Ar_mc_AKGC417L.wav
# 621 151_2p2_Ll_mc_AKGC417L.txt
# 622 151_2p2_Ll_mc_AKGC417L.wav
# 623 151_2p2_Lr_mc_AKGC417L.txt
# 624 151_2p2_Lr_mc_AKGC417L.wav
# 625 151_2p2_Pl_mc_AKGC417L.txt
# 626 151_2p2_Pl_mc_AKGC417L.wav
# 627 151_2p2_Pr_mc_AKGC417L.txt
# 628 151_2p2_Pr_mc_AKGC417L.wav
# 629 151_2p2_Tc_mc_AKGC417L.txt
# 630 151_2p2_Tc_mc_AKGC417L.wav
# 631 151_2p3_Al_mc_AKGC417L.txt
# 632 151_2p3_Al_mc_AKGC417L.wav
# 633 151_2p3_Ar_mc_AKGC417L.txt
# 634 151_2p3_Ar_mc_AKGC417L.wav
# 635 151_2p3_Ll_mc_AKGC417L.txt
# 636 151_2p3_Ll_mc_AKGC417L.wav
# 637 151_2p3_Lr_mc_AKGC417L.txt
# 638 151_2p3_Lr_mc_AKGC417L.wav
# 639 151_2p3_Pl_mc_AKGC417L.txt
# 640 151_2p3_Pl_mc_AKGC417L.wav
# 641 151_2p3_Pr_mc_AKGC417L.txt
# 642 151_2p3_Pr_mc_AKGC417L.wav
# 643 151_2p3_Tc_mc_AKGC417L.txt
# 644 151_2p3_Tc_mc_AKGC417L.wav
# 645 151_2p4_Al_mc_AKGC417L.txt
# 646 151_2p4_Al_mc_AKGC417L.wav
# 647 151_2p4_Ar_mc_AKGC417L.txt
# 648 151_2p4_Ar_mc_AKGC417L.wav
# 649 151_2p4_Ll_mc_AKGC417L.txt
# 650 151_2p4_Ll_mc_AKGC417L.wav
# 651 151_2p4_Lr_mc_AKGC417L.txt
# 652 151_2p4_Lr_mc_AKGC417L.wav
# 653 151_2p4_Pl_mc_AKGC417L.txt
# 654 151_2p4_Pl_mc_AKGC417L.wav
# 655 151_2p4_Pr_mc_AKGC417L.txt
# 656 151_2p4_Pr_mc_AKGC417L.wav
# 657 151_2p4_Tc_mc_AKGC417L.txt
# 658 151_2p4_Tc_mc_AKGC417L.wav
# 659 151_3p2_Al_mc_AKGC417L.txt
# 660 151_3p2_Al_mc_AKGC417L.wav
# 661 151_3p2_Ar_mc_AKGC417L.txt
# 662 151_3p2_Ar_mc_AKGC417L.wav
# 663 151_3p2_Lr_mc_AKGC417L.txt
# 664 151_3p2_Lr_mc_AKGC417L.wav
# 665 151_3p2_Pl_mc_AKGC417L.txt
# 666 151_3p2_Pl_mc_AKGC417L.wav
# 667 151_3p2_Pr_mc_AKGC417L.txt
# 668 151_3p2_Pr_mc_AKGC417L.wav
# 669 151_3p2_Tc_mc_AKGC417L.txt
# 670 151_3p2_Tc_mc_AKGC417L.wav
# 671 151_3p3_Ll_mc_AKGC417L.txt
# 672 151_3p3_Ll_mc_AKGC417L.wav
# 673 152_1b1_Al_sc_Meditron.txt
# 674 152_1b1_Al_sc_Meditron.wav
# 675 153_1b1_Al_sc_Meditron.txt
# 676 153_1b1_Al_sc_Meditron.wav
# 677 154_1b3_Al_mc_AKGC417L.txt
# 678 154_1b3_Al_mc_AKGC417L.wav
# 679 154_1b3_Ar_mc_AKGC417L.txt
# 680 154_1b3_Ar_mc_AKGC417L.wav
# 681 154_1b3_Ll_mc_AKGC417L.txt
# 682 154_1b3_Ll_mc_AKGC417L.wav
# 683 154_1b3_Lr_mc_AKGC417L.txt
# 684 154_1b3_Lr_mc_AKGC417L.wav
# 685 154_1b3_Pl_mc_AKGC417L.txt
# 686 154_1b3_Pl_mc_AKGC417L.wav
# 687 154_1b3_Pr_mc_AKGC417L.txt
# 688 154_1b3_Pr_mc_AKGC417L.wav
# 689 154_1b3_Tc_mc_AKGC417L.txt
# 690 154_1b3_Tc_mc_AKGC417L.wav
# 691 154_2b4_Al_mc_AKGC417L.txt
# 692 154_2b4_Al_mc_AKGC417L.wav
# 693 154_2b4_Ar_mc_AKGC417L.txt
# 694 154_2b4_Ar_mc_AKGC417L.wav
# 695 154_2b4_Ll_mc_AKGC417L.txt
# 696 154_2b4_Ll_mc_AKGC417L.wav
# 697 154_2b4_Lr_mc_AKGC417L.txt
# 698 154_2b4_Lr_mc_AKGC417L.wav
# 699 154_2b4_Pl_mc_AKGC417L.txt
# 700 154_2b4_Pl_mc_AKGC417L.wav
# 701 154_2b4_Pr_mc_AKGC417L.txt
# 702 154_2b4_Pr_mc_AKGC417L.wav
# 703 154_2b4_Tc_mc_AKGC417L.txt
# 704 154_2b4_Tc_mc_AKGC417L.wav
# 705 154_3b3_Al_mc_AKGC417L.txt
# 706 154_3b3_Al_mc_AKGC417L.wav
# 707 154_3b3_Ar_mc_AKGC417L.txt
# 708 154_3b3_Ar_mc_AKGC417L.wav
# 709 154_3b3_Ll_mc_AKGC417L.txt
# 710 154_3b3_Ll_mc_AKGC417L.wav
# 711 154_4b4_Al_mc_AKGC417L.txt
# 712 154_4b4_Al_mc_AKGC417L.wav
# 713 154_4b4_Ar_mc_AKGC417L.txt
# 714 154_4b4_Ar_mc_AKGC417L.wav
# 715 154_4b4_Ll_mc_AKGC417L.txt
# 716 154_4b4_Ll_mc_AKGC417L.wav
# 717 154_4b4_Lr_mc_AKGC417L.txt
# 718 154_4b4_Lr_mc_AKGC417L.wav
# 719 154_4b4_Pl_mc_AKGC417L.txt
# 720 154_4b4_Pl_mc_AKGC417L.wav
# 721 154_4b4_Pr_mc_AKGC417L.txt
# 722 154_4b4_Pr_mc_AKGC417L.wav
# 723 155_2b1_Al_mc_LittC2SE.txt
# 724 155_2b1_Al_mc_LittC2SE.wav
# 725 156_2b3_Al_mc_AKGC417L.txt
# 726 156_2b3_Al_mc_AKGC417L.wav
# 727 156_2b3_Ar_mc_AKGC417L.txt
# 728 156_2b3_Ar_mc_AKGC417L.wav
# 729 156_2b3_Ll_mc_AKGC417L.txt
# 730 156_2b3_Ll_mc_AKGC417L.wav
# 731 156_2b3_Lr_mc_AKGC417L.txt
# 732 156_2b3_Lr_mc_AKGC417L.wav
# 733 156_2b3_Pl_mc_AKGC417L.txt
# 734 156_2b3_Pl_mc_AKGC417L.wav
# 735 156_2b3_Pr_mc_AKGC417L.txt
# 736 156_2b3_Pr_mc_AKGC417L.wav
# 737 156_5b3_Al_mc_AKGC417L.txt
# 738 156_5b3_Al_mc_AKGC417L.wav
# 739 156_5b3_Ar_mc_AKGC417L.txt
# 740 156_5b3_Ar_mc_AKGC417L.wav
# 741 156_5b3_Ll_mc_AKGC417L.txt
# 742 156_5b3_Ll_mc_AKGC417L.wav
# 743 156_5b3_Lr_mc_AKGC417L.txt
# 744 156_5b3_Lr_mc_AKGC417L.wav
# 745 156_5b3_Pl_mc_AKGC417L.txt
# 746 156_5b3_Pl_mc_AKGC417L.wav
# 747 156_5b3_Pr_mc_AKGC417L.txt
# 748 156_5b3_Pr_mc_AKGC417L.wav
# 749 156_8b3_Al_mc_AKGC417L.txt
# 750 156_8b3_Al_mc_AKGC417L.wav
# 751 156_8b3_Ar_mc_AKGC417L.txt
# 752 156_8b3_Ar_mc_AKGC417L.wav
# 753 156_8b3_Ll_mc_AKGC417L.txt
# 754 156_8b3_Ll_mc_AKGC417L.wav
# 755 156_8b3_Lr_mc_AKGC417L.txt
# 756 156_8b3_Lr_mc_AKGC417L.wav
# 757 156_8b3_Pl_mc_AKGC417L.txt
# 758 156_8b3_Pl_mc_AKGC417L.wav
# 759 157_1b1_Al_sc_Meditron.txt
# 760 157_1b1_Al_sc_Meditron.wav
# 761 157_1b1_Ar_sc_Meditron.txt
# 762 157_1b1_Ar_sc_Meditron.wav
# 763 157_1b1_Lr_sc_Meditron.txt
# 764 157_1b1_Lr_sc_Meditron.wav
# 765 157_1b1_Pl_sc_Meditron.txt
# 766 157_1b1_Pl_sc_Meditron.wav
# 767 157_1b1_Pr_sc_Meditron.txt
# 768 157_1b1_Pr_sc_Meditron.wav
# 769 158_1b3_Ar_mc_LittC2SE.txt
# 770 158_1b3_Ar_mc_LittC2SE.wav
# 771 158_1p2_Al_mc_AKGC417L.txt
# 772 158_1p2_Al_mc_AKGC417L.wav
# 773 158_1p2_Ar_mc_AKGC417L.txt
# 774 158_1p2_Ar_mc_AKGC417L.wav
# 775 158_1p2_Ll_mc_AKGC417L.txt
# 776 158_1p2_Ll_mc_AKGC417L.wav
# 777 158_1p2_Lr_mc_AKGC417L.txt
# 778 158_1p2_Lr_mc_AKGC417L.wav
# 779 158_1p2_Pl_mc_AKGC417L.txt
# 780 158_1p2_Pl_mc_AKGC417L.wav
# 781 158_1p2_Pr_mc_AKGC417L.txt
# 782 158_1p2_Pr_mc_AKGC417L.wav
# 783 158_1p2_Tc_mc_AKGC417L.txt
# 784 158_1p2_Tc_mc_AKGC417L.wav
# 785 158_1p3_Al_mc_AKGC417L.txt
# 786 158_1p3_Al_mc_AKGC417L.wav
# 787 158_1p3_Ar_mc_AKGC417L.txt
# 788 158_1p3_Ar_mc_AKGC417L.wav
# 789 158_1p3_Ll_mc_AKGC417L.txt
# 790 158_1p3_Ll_mc_AKGC417L.wav
# 791 158_1p3_Lr_mc_AKGC417L.txt
# 792 158_1p3_Lr_mc_AKGC417L.wav
# 793 158_1p3_Pl_mc_AKGC417L.txt
# 794 158_1p3_Pl_mc_AKGC417L.wav
# 795 158_1p3_Pr_mc_AKGC417L.txt
# 796 158_1p3_Pr_mc_AKGC417L.wav
# 797 158_1p3_Tc_mc_AKGC417L.txt
# 798 158_1p3_Tc_mc_AKGC417L.wav
# 799 158_1p4_Al_mc_AKGC417L.txt
# 800 158_1p4_Al_mc_AKGC417L.wav
# 801 158_1p4_Ar_mc_AKGC417L.txt
# 802 158_1p4_Ar_mc_AKGC417L.wav
# 803 158_1p4_Lr_mc_AKGC417L.txt
# 804 158_1p4_Lr_mc_AKGC417L.wav
# 805 158_1p4_Pl_mc_AKGC417L.txt
# 806 158_1p4_Pl_mc_AKGC417L.wav
# 807 158_1p4_Pr_mc_AKGC417L.txt
# 808 158_1p4_Pr_mc_AKGC417L.wav
# 809 158_1p4_Tc_mc_AKGC417L.txt
# 810 158_1p4_Tc_mc_AKGC417L.wav
# 811 158_2p2_Ar_mc_AKGC417L.txt
# 812 158_2p2_Ar_mc_AKGC417L.wav
# 813 158_2p3_Lr_mc_AKGC417L.txt
# 814 158_2p3_Lr_mc_AKGC417L.wav
# 815 158_2p3_Tc_mc_AKGC417L.txt
# 816 158_2p3_Tc_mc_AKGC417L.wav
# 817 159_1b1_Al_sc_Meditron.txt
# 818 159_1b1_Al_sc_Meditron.wav
# 819 159_1b1_Ar_sc_Meditron.txt
# 820 159_1b1_Ar_sc_Meditron.wav
# 821 159_1b1_Ll_sc_Meditron.txt
# 822 159_1b1_Ll_sc_Meditron.wav
# 823 159_1b1_Pr_sc_Meditron.txt
# 824 159_1b1_Pr_sc_Meditron.wav
# 825 160_1b2_Al_mc_AKGC417L.txt
# 826 160_1b2_Al_mc_AKGC417L.wav
# 827 160_1b2_Ar_mc_AKGC417L.txt
# 828 160_1b2_Ar_mc_AKGC417L.wav
# 829 160_1b2_Lr_mc_AKGC417L.txt
# 830 160_1b2_Lr_mc_AKGC417L.wav
# 831 160_1b2_Pl_mc_AKGC417L.txt
# 832 160_1b2_Pl_mc_AKGC417L.wav
# 833 160_1b2_Pr_mc_AKGC417L.txt
# 834 160_1b2_Pr_mc_AKGC417L.wav
# 835 160_1b2_Tc_mc_AKGC417L.txt
# 836 160_1b2_Tc_mc_AKGC417L.wav
# 837 160_1b3_Al_mc_AKGC417L.txt
# 838 160_1b3_Al_mc_AKGC417L.wav
# 839 160_1b3_Ar_mc_AKGC417L.txt
# 840 160_1b3_Ar_mc_AKGC417L.wav
# 841 160_1b3_Lr_mc_AKGC417L.txt
# 842 160_1b3_Lr_mc_AKGC417L.wav
# 843 160_1b3_Pl_mc_AKGC417L.txt
# 844 160_1b3_Pl_mc_AKGC417L.wav
# 845 160_1b3_Pr_mc_AKGC417L.txt
# 846 160_1b3_Pr_mc_AKGC417L.wav
# 847 160_1b3_Tc_mc_AKGC417L.txt
# 848 160_1b3_Tc_mc_AKGC417L.wav
# 849 160_1b4_Al_mc_AKGC417L.txt
# 850 160_1b4_Al_mc_AKGC417L.wav
# 851 160_1b4_Ar_mc_AKGC417L.txt
# 852 160_1b4_Ar_mc_AKGC417L.wav
# 853 160_1b4_Lr_mc_AKGC417L.txt
# 854 160_1b4_Lr_mc_AKGC417L.wav
# 855 160_1b4_Pl_mc_AKGC417L.txt
# 856 160_1b4_Pl_mc_AKGC417L.wav
# 857 160_1b4_Pr_mc_AKGC417L.txt
# 858 160_1b4_Pr_mc_AKGC417L.wav
# 859 160_1b4_Tc_mc_AKGC417L.txt
# 860 160_1b4_Tc_mc_AKGC417L.wav
# 861 160_2b3_Lr_mc_AKGC417L.txt
# 862 160_2b3_Lr_mc_AKGC417L.wav
# 863 160_2b4_Ar_mc_AKGC417L.txt
# 864 160_2b4_Ar_mc_AKGC417L.wav
# 865 160_2b4_Pl_mc_AKGC417L.txt
# 866 160_2b4_Pl_mc_AKGC417L.wav
# 867 160_2b4_Pr_mc_AKGC417L.txt
# 868 160_2b4_Pr_mc_AKGC417L.wav
# 869 160_2b4_Tc_mc_AKGC417L.txt
# 870 160_2b4_Tc_mc_AKGC417L.wav
# 871 161_1b1_Al_sc_Meditron.txt
# 872 161_1b1_Al_sc_Meditron.wav
# 873 161_1b1_Pl_sc_Meditron.txt
# 874 161_1b1_Pl_sc_Meditron.wav
# 875 162_1b2_Al_mc_AKGC417L.txt
# 876 162_1b2_Al_mc_AKGC417L.wav
# 877 162_1b2_Ar_mc_AKGC417L.txt
# 878 162_1b2_Ar_mc_AKGC417L.wav
# 879 162_1b2_Ll_mc_AKGC417L.txt
# 880 162_1b2_Ll_mc_AKGC417L.wav
# 881 162_1b2_Lr_mc_AKGC417L.txt
# 882 162_1b2_Lr_mc_AKGC417L.wav
# 883 162_1b2_Pl_mc_AKGC417L.txt
# 884 162_1b2_Pl_mc_AKGC417L.wav
# 885 162_1b2_Pr_mc_AKGC417L.txt
# 886 162_1b2_Pr_mc_AKGC417L.wav
# 887 162_1b2_Tc_mc_AKGC417L.txt
# 888 162_1b2_Tc_mc_AKGC417L.wav
# 889 162_2b2_Al_mc_AKGC417L.txt
# 890 162_2b2_Al_mc_AKGC417L.wav
# 891 162_2b2_Ar_mc_AKGC417L.txt
# 892 162_2b2_Ar_mc_AKGC417L.wav
# 893 162_2b2_Pl_mc_AKGC417L.txt
# 894 162_2b2_Pl_mc_AKGC417L.wav
# 895 162_2b2_Pr_mc_AKGC417L.txt
# 896 162_2b2_Pr_mc_AKGC417L.wav
# 897 162_2b2_Tc_mc_AKGC417L.txt
# 898 162_2b2_Tc_mc_AKGC417L.wav
# 899 162_2b3_Al_mc_AKGC417L.txt
# 900 162_2b3_Al_mc_AKGC417L.wav
# 901 162_2b3_Ar_mc_AKGC417L.txt
# 902 162_2b3_Ar_mc_AKGC417L.wav
# 903 162_2b3_Lr_mc_AKGC417L.txt
# 904 162_2b3_Lr_mc_AKGC417L.wav
# 905 162_2b3_Pl_mc_AKGC417L.txt
# 906 162_2b3_Pl_mc_AKGC417L.wav
# 907 162_2b3_Pr_mc_AKGC417L.txt
# 908 162_2b3_Pr_mc_AKGC417L.wav
# 909 162_2b3_Tc_mc_AKGC417L.txt
# 910 162_2b3_Tc_mc_AKGC417L.wav
# 911 162_2b4_Al_mc_AKGC417L.txt
# 912 162_2b4_Al_mc_AKGC417L.wav
# 913 162_2b4_Ar_mc_AKGC417L.txt
# 914 162_2b4_Ar_mc_AKGC417L.wav
# 915 162_2b4_Lr_mc_AKGC417L.txt
# 916 162_2b4_Lr_mc_AKGC417L.wav
# 917 162_2b4_Pl_mc_AKGC417L.txt
# 918 162_2b4_Pl_mc_AKGC417L.wav
# 919 162_2b4_Pr_mc_AKGC417L.txt
# 920 162_2b4_Pr_mc_AKGC417L.wav
# 921 162_2b4_Tc_mc_AKGC417L.txt
# 922 162_2b4_Tc_mc_AKGC417L.wav
# 923 163_2b2_Al_mc_AKGC417L.txt
# 924 163_2b2_Al_mc_AKGC417L.wav
# 925 163_2b2_Ar_mc_AKGC417L.txt
# 926 163_2b2_Ar_mc_AKGC417L.wav
# 927 163_2b2_Ll_mc_AKGC417L.txt
# 928 163_2b2_Ll_mc_AKGC417L.wav
# 929 163_2b2_Lr_mc_AKGC417L.txt
# 930 163_2b2_Lr_mc_AKGC417L.wav
# 931 163_2b2_Pl_mc_AKGC417L.txt
# 932 163_2b2_Pl_mc_AKGC417L.wav
# 933 163_2b2_Pr_mc_AKGC417L.txt
# 934 163_2b2_Pr_mc_AKGC417L.wav
# 935 163_2b2_Tc_mc_AKGC417L.txt
# 936 163_2b2_Tc_mc_AKGC417L.wav
# 937 163_8b3_Al_mc_AKGC417L.txt
# 938 163_8b3_Al_mc_AKGC417L.wav
# 939 163_8b3_Ar_mc_AKGC417L.txt
# 940 163_8b3_Ar_mc_AKGC417L.wav
# 941 163_8b3_Ll_mc_AKGC417L.txt
# 942 163_8b3_Ll_mc_AKGC417L.wav
# 943 163_8b3_Lr_mc_AKGC417L.txt
# 944 163_8b3_Lr_mc_AKGC417L.wav
# 945 163_8b3_Pl_mc_AKGC417L.txt
# 946 163_8b3_Pl_mc_AKGC417L.wav
# 947 163_8b3_Pr_mc_AKGC417L.txt
# 948 163_8b3_Pr_mc_AKGC417L.wav
# 949 164_1b1_Ll_sc_Meditron.txt
# 950 164_1b1_Ll_sc_Meditron.wav
# 951 165_1b1_Ar_sc_Meditron.txt
# 952 165_1b1_Ar_sc_Meditron.wav
# 953 165_1b1_Pl_sc_Meditron.txt
# 954 165_1b1_Pl_sc_Meditron.wav
# 955 165_1b1_Pr_sc_Meditron.txt
# 956 165_1b1_Pr_sc_Meditron.wav
# 957 166_1p1_Al_sc_Meditron.txt
# 958 166_1p1_Al_sc_Meditron.wav
# 959 166_1p1_Ar_sc_Meditron.txt
# 960 166_1p1_Ar_sc_Meditron.wav
# 961 166_1p1_Ll_sc_Meditron.txt
# 962 166_1p1_Ll_sc_Meditron.wav
# 963 166_1p1_Pl_sc_Meditron.txt
# 964 166_1p1_Pl_sc_Meditron.wav
# 965 166_1p1_Pr_sc_Meditron.txt
# 966 166_1p1_Pr_sc_Meditron.wav
# 967 167_1b1_Al_sc_Meditron.txt
# 968 167_1b1_Al_sc_Meditron.wav
# 969 167_1b1_Pr_sc_Meditron.txt
# 970 167_1b1_Pr_sc_Meditron.wav
# 971 168_1b1_Al_sc_Meditron.txt
# 972 168_1b1_Al_sc_Meditron.wav
# 973 169_1b1_Lr_sc_Meditron.txt
# 974 169_1b1_Lr_sc_Meditron.wav
# 975 169_1b2_Ll_sc_Meditron.txt
# 976 169_1b2_Ll_sc_Meditron.wav
# 977 170_1b2_Al_mc_AKGC417L.txt
# 978 170_1b2_Al_mc_AKGC417L.wav
# 979 170_1b2_Ar_mc_AKGC417L.txt
# 980 170_1b2_Ar_mc_AKGC417L.wav
# 981 170_1b2_Lr_mc_AKGC417L.txt
# 982 170_1b2_Lr_mc_AKGC417L.wav
# 983 170_1b2_Pl_mc_AKGC417L.txt
# 984 170_1b2_Pl_mc_AKGC417L.wav
# 985 170_1b2_Pr_mc_AKGC417L.txt
# 986 170_1b2_Pr_mc_AKGC417L.wav
# 987 170_1b2_Tc_mc_AKGC417L.txt
# 988 170_1b2_Tc_mc_AKGC417L.wav
# 989 170_1b3_Al_mc_AKGC417L.txt
# 990 170_1b3_Al_mc_AKGC417L.wav
# 991 170_1b3_Ar_mc_AKGC417L.txt
# 992 170_1b3_Ar_mc_AKGC417L.wav
# 993 170_1b3_Ll_mc_AKGC417L.txt
# 994 170_1b3_Ll_mc_AKGC417L.wav
# 995 170_1b3_Lr_mc_AKGC417L.txt
# 996 170_1b3_Lr_mc_AKGC417L.wav
# 997 170_1b3_Pl_mc_AKGC417L.txt
# 998 170_1b3_Pl_mc_AKGC417L.wav
# 999 170_1b3_Pr_mc_AKGC417L.txt
# 1000 170_1b3_Pr_mc_AKGC417L.wav
# 1001 170_1b3_Tc_mc_AKGC417L.txt
# 1002 170_1b3_Tc_mc_AKGC417L.wav
# 1003 170_1b4_Al_mc_AKGC417L.txt
# 1004 170_1b4_Al_mc_AKGC417L.wav
# 1005 170_1b4_Ar_mc_AKGC417L.txt
# 1006 170_1b4_Ar_mc_AKGC417L.wav
# 1007 170_1b4_Lr_mc_AKGC417L.txt
# 1008 170_1b4_Lr_mc_AKGC417L.wav
# 1009 170_1b4_Pl_mc_AKGC417L.txt
# 1010 170_1b4_Pl_mc_AKGC417L.wav
# 1011 170_1b4_Pr_mc_AKGC417L.txt
# 1012 170_1b4_Pr_mc_AKGC417L.wav
# 1013 170_1b4_Tc_mc_AKGC417L.txt
# 1014 170_1b4_Tc_mc_AKGC417L.wav
# 1015 170_2b2_Al_mc_AKGC417L.txt
# 1016 170_2b2_Al_mc_AKGC417L.wav
# 1017 170_2b2_Ar_mc_AKGC417L.txt
# 1018 170_2b2_Ar_mc_AKGC417L.wav
# 1019 170_2b2_Lr_mc_AKGC417L.txt
# 1020 170_2b2_Lr_mc_AKGC417L.wav
# 1021 170_2b2_Pl_mc_AKGC417L.txt
# 1022 170_2b2_Pl_mc_AKGC417L.wav
# 1023 170_2b2_Pr_mc_AKGC417L.txt
# 1024 170_2b2_Pr_mc_AKGC417L.wav
# 1025 170_2b2_Tc_mc_AKGC417L.txt
# 1026 170_2b2_Tc_mc_AKGC417L.wav
# 1027 171_1b1_Al_sc_Meditron.txt
# 1028 171_1b1_Al_sc_Meditron.wav
# 1029 172_1b3_Al_mc_AKGC417L.txt
# 1030 172_1b3_Al_mc_AKGC417L.wav
# 1031 172_1b3_Ar_mc_AKGC417L.txt
# 1032 172_1b3_Ar_mc_AKGC417L.wav
# 1033 172_1b3_Ll_mc_AKGC417L.txt
# 1034 172_1b3_Ll_mc_AKGC417L.wav
# 1035 172_1b3_Lr_mc_AKGC417L.txt
# 1036 172_1b3_Lr_mc_AKGC417L.wav
# 1037 172_1b3_Pl_mc_AKGC417L.txt
# 1038 172_1b3_Pl_mc_AKGC417L.wav
# 1039 172_1b3_Pr_mc_AKGC417L.txt
# 1040 172_1b3_Pr_mc_AKGC417L.wav
# 1041 172_1b3_Tc_mc_AKGC417L.txt
# 1042 172_1b3_Tc_mc_AKGC417L.wav
# 1043 172_1b4_Al_mc_AKGC417L.txt
# 1044 172_1b4_Al_mc_AKGC417L.wav
# 1045 172_1b4_Ar_mc_AKGC417L.txt
# 1046 172_1b4_Ar_mc_AKGC417L.wav
# 1047 172_1b4_Ll_mc_AKGC417L.txt
# 1048 172_1b4_Ll_mc_AKGC417L.wav
# 1049 172_1b4_Lr_mc_AKGC417L.txt
# 1050 172_1b4_Lr_mc_AKGC417L.wav
# 1051 172_1b4_Pl_mc_AKGC417L.txt
# 1052 172_1b4_Pl_mc_AKGC417L.wav
# 1053 172_1b4_Pr_mc_AKGC417L.txt
# 1054 172_1b4_Pr_mc_AKGC417L.wav
# 1055 172_1b4_Tc_mc_AKGC417L.txt
# 1056 172_1b4_Tc_mc_AKGC417L.wav
# 1057 172_1b5_Al_mc_AKGC417L.txt
# 1058 172_1b5_Al_mc_AKGC417L.wav
# 1059 172_1b5_Ar_mc_AKGC417L.txt
# 1060 172_1b5_Ar_mc_AKGC417L.wav
# 1061 172_1b5_Ll_mc_AKGC417L.txt
# 1062 172_1b5_Ll_mc_AKGC417L.wav
# 1063 172_1b5_Lr_mc_AKGC417L.txt
# 1064 172_1b5_Lr_mc_AKGC417L.wav
# 1065 172_1b5_Pl_mc_AKGC417L.txt
# 1066 172_1b5_Pl_mc_AKGC417L.wav
# 1067 172_1b5_Pr_mc_AKGC417L.txt
# 1068 172_1b5_Pr_mc_AKGC417L.wav
# 1069 172_1b5_Tc_mc_AKGC417L.txt
# 1070 172_1b5_Tc_mc_AKGC417L.wav
# 1071 172_2b5_Al_mc_AKGC417L.txt
# 1072 172_2b5_Al_mc_AKGC417L.wav
# 1073 172_2b5_Ar_mc_AKGC417L.txt
# 1074 172_2b5_Ar_mc_AKGC417L.wav
# 1075 172_2b5_Lr_mc_AKGC417L.txt
# 1076 172_2b5_Lr_mc_AKGC417L.wav
# 1077 172_2b5_Pl_mc_AKGC417L.txt
# 1078 172_2b5_Pl_mc_AKGC417L.wav
# 1079 172_2b5_Pr_mc_AKGC417L.txt
# 1080 172_2b5_Pr_mc_AKGC417L.wav
# 1081 172_2b5_Tc_mc_AKGC417L.txt
# 1082 172_2b5_Tc_mc_AKGC417L.wav
# 1083 173_1b1_Al_sc_Meditron.txt
# 1084 173_1b1_Al_sc_Meditron.wav
# 1085 174_1p2_Ar_mc_AKGC417L.txt
# 1086 174_1p2_Ar_mc_AKGC417L.wav
# 1087 174_1p2_Ll_mc_AKGC417L.txt
# 1088 174_1p2_Ll_mc_AKGC417L.wav
# 1089 174_1p2_Lr_mc_AKGC417L.txt
# 1090 174_1p2_Lr_mc_AKGC417L.wav
# 1091 174_1p2_Pl_mc_AKGC417L.txt
# 1092 174_1p2_Pl_mc_AKGC417L.wav
# 1093 174_1p2_Pr_mc_AKGC417L.txt
# 1094 174_1p2_Pr_mc_AKGC417L.wav
# 1095 174_1p2_Tc_mc_AKGC417L.txt
# 1096 174_1p2_Tc_mc_AKGC417L.wav
# 1097 174_1p3_Ar_mc_AKGC417L.txt
# 1098 174_1p3_Ar_mc_AKGC417L.wav
# 1099 174_1p3_Ll_mc_AKGC417L.txt
# 1100 174_1p3_Ll_mc_AKGC417L.wav
# 1101 174_1p3_Lr_mc_AKGC417L.txt
# 1102 174_1p3_Lr_mc_AKGC417L.wav
# 1103 174_1p3_Pl_mc_AKGC417L.txt
# 1104 174_1p3_Pl_mc_AKGC417L.wav
# 1105 174_1p3_Pr_mc_AKGC417L.txt
# 1106 174_1p3_Pr_mc_AKGC417L.wav
# 1107 174_1p3_Tc_mc_AKGC417L.txt
# 1108 174_1p3_Tc_mc_AKGC417L.wav
# 1109 174_1p4_Ar_mc_AKGC417L.txt
# 1110 174_1p4_Ar_mc_AKGC417L.wav
# 1111 174_1p4_Ll_mc_AKGC417L.txt
# 1112 174_1p4_Ll_mc_AKGC417L.wav
# 1113 174_1p4_Lr_mc_AKGC417L.txt
# 1114 174_1p4_Lr_mc_AKGC417L.wav
# 1115 174_1p4_Pl_mc_AKGC417L.txt
# 1116 174_1p4_Pl_mc_AKGC417L.wav
# 1117 174_1p4_Pr_mc_AKGC417L.txt
# 1118 174_1p4_Pr_mc_AKGC417L.wav
# 1119 174_1p4_Tc_mc_AKGC417L.txt
# 1120 174_1p4_Tc_mc_AKGC417L.wav
# 1121 174_2p3_Al_mc_AKGC417L.txt
# 1122 174_2p3_Al_mc_AKGC417L.wav
# 1123 174_2p3_Ar_mc_AKGC417L.txt
# 1124 174_2p3_Ar_mc_AKGC417L.wav
# 1125 174_2p3_Pl_mc_AKGC417L.txt
# 1126 174_2p3_Pl_mc_AKGC417L.wav
# 1127 174_2p3_Pr_mc_AKGC417L.txt
# 1128 174_2p3_Pr_mc_AKGC417L.wav
# 1129 174_2p3_Tc_mc_AKGC417L.txt
# 1130 174_2p3_Tc_mc_AKGC417L.wav
# 1131 175_1b1_Al_sc_Litt3200.txt
# 1132 175_1b1_Al_sc_Litt3200.wav
# 1133 175_1b1_Ar_sc_Litt3200.txt
# 1134 175_1b1_Ar_sc_Litt3200.wav
# 1135 175_1b1_Ll_sc_Litt3200.txt
# 1136 175_1b1_Ll_sc_Litt3200.wav
# 1137 175_1b1_Lr_sc_Litt3200.txt
# 1138 175_1b1_Lr_sc_Litt3200.wav
# 1139 175_1b1_Pl_sc_Litt3200.txt
# 1140 175_1b1_Pl_sc_Litt3200.wav
# 1141 175_1b1_Pr_sc_Litt3200.txt
# 1142 175_1b1_Pr_sc_Litt3200.wav
# 1143 176_1b3_Al_mc_AKGC417L.txt
# 1144 176_1b3_Al_mc_AKGC417L.wav
# 1145 176_1b3_Ar_mc_AKGC417L.txt
# 1146 176_1b3_Ar_mc_AKGC417L.wav
# 1147 176_1b3_Ll_mc_AKGC417L.txt
# 1148 176_1b3_Ll_mc_AKGC417L.wav
# 1149 176_1b3_Lr_mc_AKGC417L.txt
# 1150 176_1b3_Lr_mc_AKGC417L.wav
# 1151 176_1b3_Pl_mc_AKGC417L.txt
# 1152 176_1b3_Pl_mc_AKGC417L.wav
# 1153 176_1b3_Pr_mc_AKGC417L.txt
# 1154 176_1b3_Pr_mc_AKGC417L.wav
# 1155 176_1b3_Tc_mc_AKGC417L.txt
# 1156 176_1b3_Tc_mc_AKGC417L.wav
# 1157 176_1b4_Al_mc_AKGC417L.txt
# 1158 176_1b4_Al_mc_AKGC417L.wav
# 1159 176_1b4_Ar_mc_AKGC417L.txt
# 1160 176_1b4_Ar_mc_AKGC417L.wav
# 1161 176_1b4_Ll_mc_AKGC417L.txt
# 1162 176_1b4_Ll_mc_AKGC417L.wav
# 1163 176_1b4_Lr_mc_AKGC417L.txt
# 1164 176_1b4_Lr_mc_AKGC417L.wav
# 1165 176_1b4_Pl_mc_AKGC417L.txt
# 1166 176_1b4_Pl_mc_AKGC417L.wav
# 1167 176_1b4_Pr_mc_AKGC417L.txt
# 1168 176_1b4_Pr_mc_AKGC417L.wav
# 1169 176_1b4_Tc_mc_AKGC417L.txt
# 1170 176_1b4_Tc_mc_AKGC417L.wav
# 1171 176_2b3_Al_mc_AKGC417L.txt
# 1172 176_2b3_Al_mc_AKGC417L.wav
# 1173 176_2b3_Ar_mc_AKGC417L.txt
# 1174 176_2b3_Ar_mc_AKGC417L.wav
# 1175 176_2b3_Ll_mc_AKGC417L.txt
# 1176 176_2b3_Ll_mc_AKGC417L.wav
# 1177 176_2b3_Lr_mc_AKGC417L.txt
# 1178 176_2b3_Lr_mc_AKGC417L.wav
# 1179 176_2b3_Pl_mc_AKGC417L.txt
# 1180 176_2b3_Pl_mc_AKGC417L.wav
# 1181 176_2b3_Pr_mc_AKGC417L.txt
# 1182 176_2b3_Pr_mc_AKGC417L.wav
# 1183 176_2b3_Tc_mc_AKGC417L.txt
# 1184 176_2b3_Tc_mc_AKGC417L.wav
# 1185 177_1b2_Al_mc_AKGC417L.txt
# 1186 177_1b2_Al_mc_AKGC417L.wav
# 1187 177_1b2_Ar_mc_AKGC417L.txt
# 1188 177_1b2_Ar_mc_AKGC417L.wav
# 1189 177_1b2_Lr_mc_AKGC417L.txt
# 1190 177_1b2_Lr_mc_AKGC417L.wav
# 1191 177_1b2_Pl_mc_AKGC417L.txt
# 1192 177_1b2_Pl_mc_AKGC417L.wav
# 1193 177_1b2_Pr_mc_AKGC417L.txt
# 1194 177_1b2_Pr_mc_AKGC417L.wav
# 1195 177_1b2_Tc_mc_AKGC417L.txt
# 1196 177_1b2_Tc_mc_AKGC417L.wav
# 1197 177_1b4_Al_mc_AKGC417L.txt
# 1198 177_1b4_Al_mc_AKGC417L.wav
# 1199 177_1b4_Ar_mc_AKGC417L.txt
# 1200 177_1b4_Ar_mc_AKGC417L.wav
# 1201 177_1b4_Lr_mc_AKGC417L.txt
# 1202 177_1b4_Lr_mc_AKGC417L.wav
# 1203 177_1b4_Pl_mc_AKGC417L.txt
# 1204 177_1b4_Pl_mc_AKGC417L.wav
# 1205 177_1b4_Pr_mc_AKGC417L.txt
# 1206 177_1b4_Pr_mc_AKGC417L.wav
# 1207 177_1b4_Tc_mc_AKGC417L.txt
# 1208 177_1b4_Tc_mc_AKGC417L.wav
# 1209 177_2b4_Al_mc_AKGC417L.txt
# 1210 177_2b4_Al_mc_AKGC417L.wav
# 1211 177_2b4_Lr_mc_AKGC417L.txt
# 1212 177_2b4_Lr_mc_AKGC417L.wav
# 1213 177_2b4_Pl_mc_AKGC417L.txt
# 1214 177_2b4_Pl_mc_AKGC417L.wav
# 1215 177_2b4_Pr_mc_AKGC417L.txt
# 1216 177_2b4_Pr_mc_AKGC417L.wav
# 1217 177_2b4_Tc_mc_AKGC417L.txt
# 1218 177_2b4_Tc_mc_AKGC417L.wav
# 1219 178_1b2_Al_mc_AKGC417L.txt
# 1220 178_1b2_Al_mc_AKGC417L.wav
# 1221 178_1b2_Ar_mc_AKGC417L.txt
# 1222 178_1b2_Ar_mc_AKGC417L.wav
# 1223 178_1b2_Lr_mc_AKGC417L.txt
# 1224 178_1b2_Lr_mc_AKGC417L.wav
# 1225 178_1b2_Pl_mc_AKGC417L.txt
# 1226 178_1b2_Pl_mc_AKGC417L.wav
# 1227 178_1b2_Pr_mc_AKGC417L.txt
# 1228 178_1b2_Pr_mc_AKGC417L.wav
# 1229 178_1b2_Tc_mc_AKGC417L.txt
# 1230 178_1b2_Tc_mc_AKGC417L.wav
# 1231 178_1b3_Al_mc_AKGC417L.txt
# 1232 178_1b3_Al_mc_AKGC417L.wav
# 1233 178_1b3_Ar_mc_AKGC417L.txt
# 1234 178_1b3_Ar_mc_AKGC417L.wav
# 1235 178_1b3_Lr_mc_AKGC417L.txt
# 1236 178_1b3_Lr_mc_AKGC417L.wav
# 1237 178_1b3_Pl_mc_AKGC417L.txt
# 1238 178_1b3_Pl_mc_AKGC417L.wav
# 1239 178_1b3_Pr_mc_AKGC417L.txt
# 1240 178_1b3_Pr_mc_AKGC417L.wav
# 1241 178_1b3_Tc_mc_AKGC417L.txt
# 1242 178_1b3_Tc_mc_AKGC417L.wav
# 1243 178_1b6_Al_mc_AKGC417L.txt
# 1244 178_1b6_Al_mc_AKGC417L.wav
# 1245 178_1b6_Ar_mc_AKGC417L.txt
# 1246 178_1b6_Ar_mc_AKGC417L.wav
# 1247 178_1b6_Ll_mc_AKGC417L.txt
# 1248 178_1b6_Ll_mc_AKGC417L.wav
# 1249 178_1b6_Lr_mc_AKGC417L.txt
# 1250 178_1b6_Lr_mc_AKGC417L.wav
# 1251 178_1b6_Pl_mc_AKGC417L.txt
# 1252 178_1b6_Pl_mc_AKGC417L.wav
# 1253 178_1b6_Pr_mc_AKGC417L.txt
# 1254 178_1b6_Pr_mc_AKGC417L.wav
# 1255 178_1b6_Tc_mc_AKGC417L.txt
# 1256 178_1b6_Tc_mc_AKGC417L.wav
# 1257 178_2b2_Al_mc_AKGC417L.txt
# 1258 178_2b2_Al_mc_AKGC417L.wav
# 1259 178_2b2_Ar_mc_AKGC417L.txt
# 1260 178_2b2_Ar_mc_AKGC417L.wav
# 1261 178_2b2_Lr_mc_AKGC417L.txt
# 1262 178_2b2_Lr_mc_AKGC417L.wav
# 1263 178_2b2_Pr_mc_AKGC417L.txt
# 1264 178_2b2_Pr_mc_AKGC417L.wav
# 1265 178_2b2_Tc_mc_AKGC417L.txt
# 1266 178_2b2_Tc_mc_AKGC417L.wav
# 1267 179_1b1_Al_sc_Meditron.txt
# 1268 179_1b1_Al_sc_Meditron.wav
# 1269 179_1b1_Tc_sc_Meditron.txt
# 1270 179_1b1_Tc_sc_Meditron.wav
# 1271 180_1b4_Al_mc_AKGC417L.txt
# 1272 180_1b4_Al_mc_AKGC417L.wav
# 1273 180_1b4_Ar_mc_AKGC417L.txt
# 1274 180_1b4_Ar_mc_AKGC417L.wav
# 1275 180_1b4_Lr_mc_AKGC417L.txt
# 1276 180_1b4_Lr_mc_AKGC417L.wav
# 1277 180_1b4_Pl_mc_AKGC417L.txt
# 1278 180_1b4_Pl_mc_AKGC417L.wav
# 1279 180_1b4_Pr_mc_AKGC417L.txt
# 1280 180_1b4_Pr_mc_AKGC417L.wav
# 1281 181_1b1_Ar_mc_LittC2SE.txt
# 1282 181_1b1_Ar_mc_LittC2SE.wav
# 1283 181_1b1_Tc_mc_LittC2SE.txt
# 1284 181_1b1_Tc_mc_LittC2SE.wav
# 1285 181_1b2_Ar_mc_LittC2SE.txt
# 1286 181_1b2_Ar_mc_LittC2SE.wav
# 1287 181_1b3_Tc_mc_LittC2SE.txt
# 1288 181_1b3_Tc_mc_LittC2SE.wav
# 1289 182_1b1_Tc_sc_Meditron.txt
# 1290 182_1b1_Tc_sc_Meditron.wav
# 1291 183_1b1_Pl_sc_Meditron.txt
# 1292 183_1b1_Pl_sc_Meditron.wav
# 1293 183_1b1_Tc_sc_Meditron.txt
# 1294 183_1b1_Tc_sc_Meditron.wav
# 1295 184_1b1_Ar_sc_Meditron.txt
# 1296 184_1b1_Ar_sc_Meditron.wav
# 1297 185_1b1_Al_sc_Litt3200.txt
# 1298 185_1b1_Al_sc_Litt3200.wav
# 1299 185_1b1_Ar_sc_Litt3200.txt
# 1300 185_1b1_Ar_sc_Litt3200.wav
# 1301 185_1b1_Ll_sc_Litt3200.txt
# 1302 185_1b1_Ll_sc_Litt3200.wav
# 1303 185_1b1_Lr_sc_Litt3200.txt
# 1304 185_1b1_Lr_sc_Litt3200.wav
# 1305 185_1b1_Pl_sc_Litt3200.txt
# 1306 185_1b1_Pl_sc_Litt3200.wav
# 1307 185_1b1_Pr_sc_Litt3200.txt
# 1308 185_1b1_Pr_sc_Litt3200.wav
# 1309 186_2b2_Al_mc_AKGC417L.txt
# 1310 186_2b2_Al_mc_AKGC417L.wav
# 1311 186_2b2_Ar_mc_AKGC417L.txt
# 1312 186_2b2_Ar_mc_AKGC417L.wav
# 1313 186_2b2_Lr_mc_AKGC417L.txt
# 1314 186_2b2_Lr_mc_AKGC417L.wav
# 1315 186_2b2_Pl_mc_AKGC417L.txt
# 1316 186_2b2_Pl_mc_AKGC417L.wav
# 1317 186_2b2_Pr_mc_AKGC417L.txt
# 1318 186_2b2_Pr_mc_AKGC417L.wav
# 1319 186_2b2_Tc_mc_AKGC417L.txt
# 1320 186_2b2_Tc_mc_AKGC417L.wav
# 1321 186_2b3_Al_mc_AKGC417L.txt
# 1322 186_2b3_Al_mc_AKGC417L.wav
# 1323 186_2b3_Ar_mc_AKGC417L.txt
# 1324 186_2b3_Ar_mc_AKGC417L.wav
# 1325 186_2b3_Lr_mc_AKGC417L.txt
# 1326 186_2b3_Lr_mc_AKGC417L.wav
# 1327 186_2b3_Pl_mc_AKGC417L.txt
# 1328 186_2b3_Pl_mc_AKGC417L.wav
# 1329 186_2b3_Pr_mc_AKGC417L.txt
# 1330 186_2b3_Pr_mc_AKGC417L.wav
# 1331 186_2b3_Tc_mc_AKGC417L.txt
# 1332 186_2b3_Tc_mc_AKGC417L.wav
# 1333 186_2b4_Al_mc_AKGC417L.txt
# 1334 186_2b4_Al_mc_AKGC417L.wav
# 1335 186_2b4_Ar_mc_AKGC417L.txt
# 1336 186_2b4_Ar_mc_AKGC417L.wav
# 1337 186_2b4_Lr_mc_AKGC417L.txt
# 1338 186_2b4_Lr_mc_AKGC417L.wav
# 1339 186_2b4_Pl_mc_AKGC417L.txt
# 1340 186_2b4_Pl_mc_AKGC417L.wav
# 1341 186_2b4_Pr_mc_AKGC417L.txt
# 1342 186_2b4_Pr_mc_AKGC417L.wav
# 1343 186_2b4_Tc_mc_AKGC417L.txt
# 1344 186_2b4_Tc_mc_AKGC417L.wav
# 1345 186_3b3_Al_mc_AKGC417L.txt
# 1346 186_3b3_Al_mc_AKGC417L.wav
# 1347 186_3b3_Ar_mc_AKGC417L.txt
# 1348 186_3b3_Ar_mc_AKGC417L.wav
# 1349 186_3b3_Lr_mc_AKGC417L.txt
# 1350 186_3b3_Lr_mc_AKGC417L.wav
# 1351 186_3b3_Pl_mc_AKGC417L.txt
# 1352 186_3b3_Pl_mc_AKGC417L.wav
# 1353 186_3b3_Pr_mc_AKGC417L.txt
# 1354 186_3b3_Pr_mc_AKGC417L.wav
# 1355 186_3b3_Tc_mc_AKGC417L.txt
# 1356 186_3b3_Tc_mc_AKGC417L.wav
# 1357 187_1b1_Ll_sc_Meditron.txt
# 1358 187_1b1_Ll_sc_Meditron.wav
# 1359 188_1b1_Al_sc_Meditron.txt
# 1360 188_1b1_Al_sc_Meditron.wav
# 1361 188_1b1_Ar_sc_Meditron.txt
# 1362 188_1b1_Ar_sc_Meditron.wav
# 1363 188_1b1_Pl_sc_Meditron.txt
# 1364 188_1b1_Pl_sc_Meditron.wav
# 1365 188_1b1_Tc_sc_Meditron.txt
# 1366 188_1b1_Tc_sc_Meditron.wav
# 1367 189_1b2_Lr_mc_LittC2SE.txt
# 1368 189_1b2_Lr_mc_LittC2SE.wav
# 1369 190_1b1_Tc_sc_Meditron.txt
# 1370 190_1b1_Tc_sc_Meditron.wav
# 1371 191_2b1_Pl_mc_LittC2SE.txt
# 1372 191_2b1_Pl_mc_LittC2SE.wav
# 1373 191_2b1_Pr_mc_LittC2SE.txt
# 1374 191_2b1_Pr_mc_LittC2SE.wav
# 1375 191_2b2_Tc_mc_LittC2SE.txt
# 1376 191_2b2_Tc_mc_LittC2SE.wav
# 1377 192_2b1_Al_mc_LittC2SE.txt
# 1378 192_2b1_Al_mc_LittC2SE.wav
# 1379 192_2b1_Ar_mc_LittC2SE.txt
# 1380 192_2b1_Ar_mc_LittC2SE.wav
# 1381 192_2b2_Al_mc_LittC2SE.txt
# 1382 192_2b2_Al_mc_LittC2SE.wav
# 1383 192_2b2_Ar_mc_LittC2SE.txt
# 1384 192_2b2_Ar_mc_LittC2SE.wav
# 1385 192_2b3_Al_mc_LittC2SE.txt
# 1386 192_2b3_Al_mc_LittC2SE.wav
# 1387 192_2b3_Ar_mc_LittC2SE.txt
# 1388 192_2b3_Ar_mc_LittC2SE.wav
# 1389 193_1b2_Al_mc_AKGC417L.txt
# 1390 193_1b2_Al_mc_AKGC417L.wav
# 1391 193_1b2_Ar_mc_AKGC417L.txt
# 1392 193_1b2_Ar_mc_AKGC417L.wav
# 1393 193_1b2_Ll_mc_AKGC417L.txt
# 1394 193_1b2_Ll_mc_AKGC417L.wav
# 1395 193_1b2_Pl_mc_AKGC417L.txt
# 1396 193_1b2_Pl_mc_AKGC417L.wav
# 1397 193_1b2_Pr_mc_AKGC417L.txt
# 1398 193_1b2_Pr_mc_AKGC417L.wav
# 1399 193_1b2_Tc_mc_AKGC417L.txt
# 1400 193_1b2_Tc_mc_AKGC417L.wav
# 1401 193_1b4_Lr_mc_AKGC417L.txt
# 1402 193_1b4_Lr_mc_AKGC417L.wav
# 1403 193_7b3_Al_mc_AKGC417L.txt
# 1404 193_7b3_Al_mc_AKGC417L.wav
# 1405 193_7b3_Ar_mc_AKGC417L.txt
# 1406 193_7b3_Ar_mc_AKGC417L.wav
# 1407 193_7b3_Ll_mc_AKGC417L.txt
# 1408 193_7b3_Ll_mc_AKGC417L.wav
# 1409 193_7b3_Lr_mc_AKGC417L.txt
# 1410 193_7b3_Lr_mc_AKGC417L.wav
# 1411 193_7b3_Pl_mc_AKGC417L.txt
# 1412 193_7b3_Pl_mc_AKGC417L.wav
# 1413 193_7b3_Pr_mc_AKGC417L.txt
# 1414 193_7b3_Pr_mc_AKGC417L.wav
# 1415 193_7b3_Tc_mc_AKGC417L.txt
# 1416 193_7b3_Tc_mc_AKGC417L.wav
# 1417 194_1b1_Lr_sc_Meditron.txt
# 1418 194_1b1_Lr_sc_Meditron.wav
# 1419 194_1b1_Pr_sc_Meditron.txt
# 1420 194_1b1_Pr_sc_Meditron.wav
# 1421 195_1b1_Al_sc_Litt3200.txt
# 1422 195_1b1_Al_sc_Litt3200.wav
# 1423 195_1b1_Ar_sc_Litt3200.txt
# 1424 195_1b1_Ar_sc_Litt3200.wav
# 1425 195_1b1_Ll_sc_Litt3200.txt
# 1426 195_1b1_Ll_sc_Litt3200.wav
# 1427 195_1b1_Lr_sc_Litt3200.txt
# 1428 195_1b1_Lr_sc_Litt3200.wav
# 1429 195_1b1_Pl_sc_Litt3200.txt
# 1430 195_1b1_Pl_sc_Litt3200.wav
# 1431 195_1b1_Pr_sc_Litt3200.txt
# 1432 195_1b1_Pr_sc_Litt3200.wav
# 1433 196_1b1_Pr_sc_Meditron.txt
# 1434 196_1b1_Pr_sc_Meditron.wav
# 1435 197_1b1_Al_sc_Meditron.txt
# 1436 197_1b1_Al_sc_Meditron.wav
# 1437 197_1b1_Tc_sc_Meditron.txt
# 1438 197_1b1_Tc_sc_Meditron.wav
# 1439 198_1b5_Al_mc_AKGC417L.txt
# 1440 198_1b5_Al_mc_AKGC417L.wav
# 1441 198_1b5_Ar_mc_AKGC417L.txt
# 1442 198_1b5_Ar_mc_AKGC417L.wav
# 1443 198_1b5_Ll_mc_AKGC417L.txt
# 1444 198_1b5_Ll_mc_AKGC417L.wav
# 1445 198_1b5_Lr_mc_AKGC417L.txt
# 1446 198_1b5_Lr_mc_AKGC417L.wav
# 1447 198_1b5_Pl_mc_AKGC417L.txt
# 1448 198_1b5_Pl_mc_AKGC417L.wav
# 1449 198_1b5_Pr_mc_AKGC417L.txt
# 1450 198_1b5_Pr_mc_AKGC417L.wav
# 1451 198_1b5_Tc_mc_AKGC417L.txt
# 1452 198_1b5_Tc_mc_AKGC417L.wav
# 1453 198_6p1_Al_mc_AKGC417L.txt
# 1454 198_6p1_Al_mc_AKGC417L.wav
# 1455 198_6p1_Ar_mc_AKGC417L.txt
# 1456 198_6p1_Ar_mc_AKGC417L.wav
# 1457 198_6p1_Ll_mc_AKGC417L.txt
# 1458 198_6p1_Ll_mc_AKGC417L.wav
# 1459 198_6p1_Lr_mc_AKGC417L.txt
# 1460 198_6p1_Lr_mc_AKGC417L.wav
# 1461 198_6p1_Pl_mc_AKGC417L.txt
# 1462 198_6p1_Pl_mc_AKGC417L.wav
# 1463 198_6p1_Pr_mc_AKGC417L.txt
# 1464 198_6p1_Pr_mc_AKGC417L.wav
# 1465 198_6p1_Tc_mc_AKGC417L.txt
# 1466 198_6p1_Tc_mc_AKGC417L.wav
# 1467 199_2b1_Ll_mc_LittC2SE.txt
# 1468 199_2b1_Ll_mc_LittC2SE.wav
# 1469 199_2b3_Ll_mc_LittC2SE.txt
# 1470 199_2b3_Ll_mc_LittC2SE.wav
# 1471 200_2p2_Al_mc_AKGC417L.txt
# 1472 200_2p2_Al_mc_AKGC417L.wav
# 1473 200_2p2_Ar_mc_AKGC417L.txt
# 1474 200_2p2_Ar_mc_AKGC417L.wav
# 1475 200_2p2_Lr_mc_AKGC417L.txt
# 1476 200_2p2_Lr_mc_AKGC417L.wav
# 1477 200_2p2_Pl_mc_AKGC417L.txt
# 1478 200_2p2_Pl_mc_AKGC417L.wav
# 1479 200_2p2_Pr_mc_AKGC417L.txt
# 1480 200_2p2_Pr_mc_AKGC417L.wav
# 1481 200_2p2_Tc_mc_AKGC417L.txt
# 1482 200_2p2_Tc_mc_AKGC417L.wav
# 1483 200_2p3_Al_mc_AKGC417L.txt
# 1484 200_2p3_Al_mc_AKGC417L.wav
# 1485 200_2p3_Ar_mc_AKGC417L.txt
# 1486 200_2p3_Ar_mc_AKGC417L.wav
# 1487 200_2p3_Lr_mc_AKGC417L.txt
# 1488 200_2p3_Lr_mc_AKGC417L.wav
# 1489 200_2p3_Pl_mc_AKGC417L.txt
# 1490 200_2p3_Pl_mc_AKGC417L.wav
# 1491 200_2p3_Pr_mc_AKGC417L.txt
# 1492 200_2p3_Pr_mc_AKGC417L.wav
# 1493 200_2p3_Tc_mc_AKGC417L.txt
# 1494 200_2p3_Tc_mc_AKGC417L.wav
# 1495 200_2p4_Al_mc_AKGC417L.txt
# 1496 200_2p4_Al_mc_AKGC417L.wav
# 1497 200_2p4_Ar_mc_AKGC417L.txt
# 1498 200_2p4_Ar_mc_AKGC417L.wav
# 1499 200_2p4_Lr_mc_AKGC417L.txt
# 1500 200_2p4_Lr_mc_AKGC417L.wav
# 1501 200_2p4_Pl_mc_AKGC417L.txt
# 1502 200_2p4_Pl_mc_AKGC417L.wav
# 1503 200_2p4_Pr_mc_AKGC417L.txt
# 1504 200_2p4_Pr_mc_AKGC417L.wav
# 1505 200_2p4_Tc_mc_AKGC417L.txt
# 1506 200_2p4_Tc_mc_AKGC417L.wav
# 1507 200_3p4_Al_mc_AKGC417L.txt
# 1508 200_3p4_Al_mc_AKGC417L.wav
# 1509 200_3p4_Ar_mc_AKGC417L.txt
# 1510 200_3p4_Ar_mc_AKGC417L.wav
# 1511 200_3p4_Pl_mc_AKGC417L.txt
# 1512 200_3p4_Pl_mc_AKGC417L.wav
# 1513 200_3p4_Pr_mc_AKGC417L.txt
# 1514 200_3p4_Pr_mc_AKGC417L.wav
# 1515 200_3p4_Tc_mc_AKGC417L.txt
# 1516 200_3p4_Tc_mc_AKGC417L.wav
# 1517 201_1b1_Al_sc_Meditron.txt
# 1518 201_1b1_Al_sc_Meditron.wav
# 1519 201_1b1_Ar_sc_Meditron.txt
# 1520 201_1b1_Ar_sc_Meditron.wav
# 1521 201_1b2_Al_sc_Meditron.txt
# 1522 201_1b2_Al_sc_Meditron.wav
# 1523 201_1b2_Ar_sc_Meditron.txt
# 1524 201_1b2_Ar_sc_Meditron.wav
# 1525 201_1b3_Al_sc_Meditron.txt
# 1526 201_1b3_Al_sc_Meditron.wav
# 1527 201_1b3_Ar_sc_Meditron.txt
# 1528 201_1b3_Ar_sc_Meditron.wav
# 1529 202_1b1_Ar_sc_Meditron.txt
# 1530 202_1b1_Ar_sc_Meditron.wav
# 1531 203_1p2_Al_mc_AKGC417L.txt
# 1532 203_1p2_Al_mc_AKGC417L.wav
# 1533 203_1p2_Ar_mc_AKGC417L.txt
# 1534 203_1p2_Ar_mc_AKGC417L.wav
# 1535 203_1p2_Lr_mc_AKGC417L.txt
# 1536 203_1p2_Lr_mc_AKGC417L.wav
# 1537 203_1p2_Pl_mc_AKGC417L.txt
# 1538 203_1p2_Pl_mc_AKGC417L.wav
# 1539 203_1p2_Pr_mc_AKGC417L.txt
# 1540 203_1p2_Pr_mc_AKGC417L.wav
# 1541 203_1p2_Tc_mc_AKGC417L.txt
# 1542 203_1p2_Tc_mc_AKGC417L.wav
# 1543 203_1p3_Al_mc_AKGC417L.txt
# 1544 203_1p3_Al_mc_AKGC417L.wav
# 1545 203_1p3_Ar_mc_AKGC417L.txt
# 1546 203_1p3_Ar_mc_AKGC417L.wav
# 1547 203_1p3_Pl_mc_AKGC417L.txt
# 1548 203_1p3_Pl_mc_AKGC417L.wav
# 1549 203_1p3_Pr_mc_AKGC417L.txt
# 1550 203_1p3_Pr_mc_AKGC417L.wav
# 1551 203_1p3_Tc_mc_AKGC417L.txt
# 1552 203_1p3_Tc_mc_AKGC417L.wav
# 1553 203_1p4_Al_mc_AKGC417L.txt
# 1554 203_1p4_Al_mc_AKGC417L.wav
# 1555 203_1p4_Ar_mc_AKGC417L.txt
# 1556 203_1p4_Ar_mc_AKGC417L.wav
# 1557 203_1p4_Pl_mc_AKGC417L.txt
# 1558 203_1p4_Pl_mc_AKGC417L.wav
# 1559 203_1p4_Pr_mc_AKGC417L.txt
# 1560 203_1p4_Pr_mc_AKGC417L.wav
# 1561 203_1p4_Tc_mc_AKGC417L.txt
# 1562 203_1p4_Tc_mc_AKGC417L.wav
# 1563 203_2p3_Al_mc_AKGC417L.txt
# 1564 203_2p3_Al_mc_AKGC417L.wav
# 1565 203_2p3_Ar_mc_AKGC417L.txt
# 1566 203_2p3_Ar_mc_AKGC417L.wav
# 1567 203_2p3_Pl_mc_AKGC417L.txt
# 1568 203_2p3_Pl_mc_AKGC417L.wav
# 1569 203_2p3_Pr_mc_AKGC417L.txt
# 1570 203_2p3_Pr_mc_AKGC417L.wav
# 1571 203_2p3_Tc_mc_AKGC417L.txt
# 1572 203_2p3_Tc_mc_AKGC417L.wav
# 1573 204_2b5_Al_mc_AKGC417L.txt
# 1574 204_2b5_Al_mc_AKGC417L.wav
# 1575 204_2b5_Ar_mc_AKGC417L.txt
# 1576 204_2b5_Ar_mc_AKGC417L.wav
# 1577 204_2b5_Ll_mc_AKGC417L.txt
# 1578 204_2b5_Ll_mc_AKGC417L.wav
# 1579 204_7p5_Al_mc_AKGC417L.txt
# 1580 204_7p5_Al_mc_AKGC417L.wav
# 1581 204_7p5_Ar_mc_AKGC417L.txt
# 1582 204_7p5_Ar_mc_AKGC417L.wav
# 1583 204_7p5_Ll_mc_AKGC417L.txt
# 1584 204_7p5_Ll_mc_AKGC417L.wav
# 1585 204_7p5_Lr_mc_AKGC417L.txt
# 1586 204_7p5_Lr_mc_AKGC417L.wav
# 1587 204_7p5_Pr_mc_AKGC417L.txt
# 1588 204_7p5_Pr_mc_AKGC417L.wav
# 1589 204_7p5_Tc_mc_AKGC417L.txt
# 1590 204_7p5_Tc_mc_AKGC417L.wav
# 1591 205_1b3_Al_mc_AKGC417L.txt
# 1592 205_1b3_Al_mc_AKGC417L.wav
# 1593 205_1b3_Ar_mc_AKGC417L.txt
# 1594 205_1b3_Ar_mc_AKGC417L.wav
# 1595 205_1b3_Ll_mc_AKGC417L.txt
# 1596 205_1b3_Ll_mc_AKGC417L.wav
# 1597 205_1b3_Lr_mc_AKGC417L.txt
# 1598 205_1b3_Lr_mc_AKGC417L.wav
# 1599 205_1b3_Pl_mc_AKGC417L.txt
# 1600 205_1b3_Pl_mc_AKGC417L.wav
# 1601 205_1b3_Pr_mc_AKGC417L.txt
# 1602 205_1b3_Pr_mc_AKGC417L.wav
# 1603 205_2b2_Pr_mc_AKGC417L.txt
# 1604 205_2b2_Pr_mc_AKGC417L.wav
# 1605 205_2b3_Al_mc_AKGC417L.txt
# 1606 205_2b3_Al_mc_AKGC417L.wav
# 1607 205_2b3_Ar_mc_AKGC417L.txt
# 1608 205_2b3_Ar_mc_AKGC417L.wav
# 1609 205_2b3_Ll_mc_AKGC417L.txt
# 1610 205_2b3_Ll_mc_AKGC417L.wav
# 1611 205_2b4_Pl_mc_AKGC417L.txt
# 1612 205_2b4_Pl_mc_AKGC417L.wav
# 1613 205_3b4_Al_mc_AKGC417L.txt
# 1614 205_3b4_Al_mc_AKGC417L.wav
# 1615 205_3b4_Ar_mc_AKGC417L.txt
# 1616 205_3b4_Ar_mc_AKGC417L.wav
# 1617 205_3b4_Pl_mc_AKGC417L.txt
# 1618 205_3b4_Pl_mc_AKGC417L.wav
# 1619 205_3b4_Pr_mc_AKGC417L.txt
# 1620 205_3b4_Pr_mc_AKGC417L.wav
# 1621 205_4b2_Al_mc_AKGC417L.txt
# 1622 205_4b2_Al_mc_AKGC417L.wav
# 1623 205_4b2_Ar_mc_AKGC417L.txt
# 1624 205_4b2_Ar_mc_AKGC417L.wav
# 1625 205_4b2_Lr_mc_AKGC417L.txt
# 1626 205_4b2_Lr_mc_AKGC417L.wav
# 1627 205_4b2_Pl_mc_AKGC417L.txt
# 1628 205_4b2_Pl_mc_AKGC417L.wav
# 1629 205_4b2_Pr_mc_AKGC417L.txt
# 1630 205_4b2_Pr_mc_AKGC417L.wav
# 1631 206_1b1_Ar_sc_Meditron.txt
# 1632 206_1b1_Ar_sc_Meditron.wav
# 1633 206_1b1_Lr_sc_Meditron.txt
# 1634 206_1b1_Lr_sc_Meditron.wav
# 1635 206_1b1_Pl_sc_Meditron.txt
# 1636 206_1b1_Pl_sc_Meditron.wav
# 1637 207_2b2_Al_mc_AKGC417L.txt
# 1638 207_2b2_Al_mc_AKGC417L.wav
# 1639 207_2b2_Ar_mc_AKGC417L.txt
# 1640 207_2b2_Ar_mc_AKGC417L.wav
# 1641 207_2b2_Pl_mc_AKGC417L.txt
# 1642 207_2b2_Pl_mc_AKGC417L.wav
# 1643 207_2b2_Pr_mc_AKGC417L.txt
# 1644 207_2b2_Pr_mc_AKGC417L.wav
# 1645 207_2b2_Tc_mc_AKGC417L.txt
# 1646 207_2b2_Tc_mc_AKGC417L.wav
# 1647 207_2b3_Al_mc_AKGC417L.txt
# 1648 207_2b3_Al_mc_AKGC417L.wav
# 1649 207_2b3_Ar_mc_AKGC417L.txt
# 1650 207_2b3_Ar_mc_AKGC417L.wav
# 1651 207_2b3_Pl_mc_AKGC417L.txt
# 1652 207_2b3_Pl_mc_AKGC417L.wav
# 1653 207_2b3_Pr_mc_AKGC417L.txt
# 1654 207_2b3_Pr_mc_AKGC417L.wav
# 1655 207_2b3_Tc_mc_AKGC417L.txt
# 1656 207_2b3_Tc_mc_AKGC417L.wav
# 1657 207_2b4_Al_mc_AKGC417L.txt
# 1658 207_2b4_Al_mc_AKGC417L.wav
# 1659 207_2b4_Ar_mc_AKGC417L.txt
# 1660 207_2b4_Ar_mc_AKGC417L.wav
# 1661 207_2b4_Pl_mc_AKGC417L.txt
# 1662 207_2b4_Pl_mc_AKGC417L.wav
# 1663 207_2b4_Pr_mc_AKGC417L.txt
# 1664 207_2b4_Pr_mc_AKGC417L.wav
# 1665 207_2b4_Tc_mc_AKGC417L.txt
# 1666 207_2b4_Tc_mc_AKGC417L.wav
# 1667 207_3b2_Al_mc_AKGC417L.txt
# 1668 207_3b2_Al_mc_AKGC417L.wav
# 1669 207_3b2_Ar_mc_AKGC417L.txt
# 1670 207_3b2_Ar_mc_AKGC417L.wav
# 1671 207_3b2_Lr_mc_AKGC417L.txt
# 1672 207_3b2_Lr_mc_AKGC417L.wav
# 1673 207_3b2_Pl_mc_AKGC417L.txt
# 1674 207_3b2_Pl_mc_AKGC417L.wav
# 1675 207_3b2_Pr_mc_AKGC417L.txt
# 1676 207_3b2_Pr_mc_AKGC417L.wav
# 1677 207_3b2_Tc_mc_AKGC417L.txt
# 1678 207_3b2_Tc_mc_AKGC417L.wav
# 1679 208_1b1_Ll_sc_Meditron.txt
# 1680 208_1b1_Ll_sc_Meditron.wav
# 1681 209_1b1_Tc_sc_Meditron.txt
# 1682 209_1b1_Tc_sc_Meditron.wav
# 1683 210_1b1_Al_sc_Meditron.txt
# 1684 210_1b1_Al_sc_Meditron.wav
# 1685 210_1b1_Ar_sc_Meditron.txt
# 1686 210_1b1_Ar_sc_Meditron.wav
# 1687 211_1p2_Ar_mc_AKGC417L.txt
# 1688 211_1p2_Ar_mc_AKGC417L.wav
# 1689 211_1p2_Pl_mc_AKGC417L.txt
# 1690 211_1p2_Pl_mc_AKGC417L.wav
# 1691 211_1p2_Pr_mc_AKGC417L.txt
# 1692 211_1p2_Pr_mc_AKGC417L.wav
# 1693 211_1p3_Ar_mc_AKGC417L.txt
# 1694 211_1p3_Ar_mc_AKGC417L.wav
# 1695 211_1p5_Ar_mc_AKGC417L.txt
# 1696 211_1p5_Ar_mc_AKGC417L.wav
# 1697 211_2p2_Tc_mc_AKGC417L.txt
# 1698 211_2p2_Tc_mc_AKGC417L.wav
# 1699 211_2p3_Tc_mc_AKGC417L.txt
# 1700 211_2p3_Tc_mc_AKGC417L.wav
# 1701 211_2p4_Tc_mc_AKGC417L.txt
# 1702 211_2p4_Tc_mc_AKGC417L.wav
# 1703 212_2b2_Tc_mc_LittC2SE.txt
# 1704 212_2b2_Tc_mc_LittC2SE.wav
# 1705 213_1p2_Al_mc_AKGC417L.txt
# 1706 213_1p2_Al_mc_AKGC417L.wav
# 1707 213_1p2_Ar_mc_AKGC417L.txt
# 1708 213_1p2_Ar_mc_AKGC417L.wav
# 1709 213_1p2_Lr_mc_AKGC417L.txt
# 1710 213_1p2_Lr_mc_AKGC417L.wav
# 1711 213_1p2_Pl_mc_AKGC417L.txt
# 1712 213_1p2_Pl_mc_AKGC417L.wav
# 1713 213_1p2_Pr_mc_AKGC417L.txt
# 1714 213_1p2_Pr_mc_AKGC417L.wav
# 1715 213_1p2_Tc_mc_AKGC417L.txt
# 1716 213_1p2_Tc_mc_AKGC417L.wav
# 1717 213_1p3_Al_mc_AKGC417L.txt
# 1718 213_1p3_Al_mc_AKGC417L.wav
# 1719 213_1p3_Ar_mc_AKGC417L.txt
# 1720 213_1p3_Ar_mc_AKGC417L.wav
# 1721 213_1p3_Pl_mc_AKGC417L.txt
# 1722 213_1p3_Pl_mc_AKGC417L.wav
# 1723 213_1p3_Pr_mc_AKGC417L.txt
# 1724 213_1p3_Pr_mc_AKGC417L.wav
# 1725 213_1p5_Al_mc_AKGC417L.txt
# 1726 213_1p5_Al_mc_AKGC417L.wav
# 1727 213_1p5_Ar_mc_AKGC417L.txt
# 1728 213_1p5_Ar_mc_AKGC417L.wav
# 1729 213_1p5_Pl_mc_AKGC417L.txt
# 1730 213_1p5_Pl_mc_AKGC417L.wav
# 1731 213_1p5_Pr_mc_AKGC417L.txt
# 1732 213_1p5_Pr_mc_AKGC417L.wav
# 1733 213_1p5_Tc_mc_AKGC417L.txt
# 1734 213_1p5_Tc_mc_AKGC417L.wav
# 1735 213_2p2_Al_mc_AKGC417L.txt
# 1736 213_2p2_Al_mc_AKGC417L.wav
# 1737 213_2p2_Ar_mc_AKGC417L.txt
# 1738 213_2p2_Ar_mc_AKGC417L.wav
# 1739 213_2p2_Pl_mc_AKGC417L.txt
# 1740 213_2p2_Pl_mc_AKGC417L.wav
# 1741 213_2p2_Pr_mc_AKGC417L.txt
# 1742 213_2p2_Pr_mc_AKGC417L.wav
# 1743 213_2p2_Tc_mc_AKGC417L.txt
# 1744 213_2p2_Tc_mc_AKGC417L.wav
# 1745 214_1b1_Ar_sc_Meditron.txt
# 1746 214_1b1_Ar_sc_Meditron.wav
# 1747 215_1b2_Ar_sc_Meditron.txt
# 1748 215_1b2_Ar_sc_Meditron.wav
# 1749 215_1b3_Tc_sc_Meditron.txt
# 1750 215_1b3_Tc_sc_Meditron.wav
# 1751 216_1b1_Al_sc_Meditron.txt
# 1752 216_1b1_Al_sc_Meditron.wav
# 1753 216_1b1_Pl_sc_Meditron.txt
# 1754 216_1b1_Pl_sc_Meditron.wav
# 1755 217_1b1_Tc_sc_Meditron.txt
# 1756 217_1b1_Tc_sc_Meditron.wav
# 1757 218_1b1_Al_sc_Meditron.txt
# 1758 218_1b1_Al_sc_Meditron.wav
# 1759 218_1b1_Ar_sc_Meditron.txt
# 1760 218_1b1_Ar_sc_Meditron.wav
# 1761 218_1b1_Lr_sc_Meditron.txt
# 1762 218_1b1_Lr_sc_Meditron.wav
# 1763 218_1b1_Pl_sc_Meditron.txt
# 1764 218_1b1_Pl_sc_Meditron.wav
# 1765 218_1b1_Pr_sc_Meditron.txt
# 1766 218_1b1_Pr_sc_Meditron.wav
# 1767 218_1p1_Ar_sc_Litt3200.txt
# 1768 218_1p1_Ar_sc_Litt3200.wav
# 1769 218_1p1_Pl_sc_Litt3200.txt
# 1770 218_1p1_Pl_sc_Litt3200.wav
# 1771 218_1p1_Pr_sc_Litt3200.txt
# 1772 218_1p1_Pr_sc_Litt3200.wav
# 1773 219_2b1_Ar_mc_LittC2SE.txt
# 1774 219_2b1_Ar_mc_LittC2SE.wav
# 1775 219_2b1_Tc_mc_LittC2SE.txt
# 1776 219_2b1_Tc_mc_LittC2SE.wav
# 1777 219_2b2_Ar_mc_LittC2SE.txt
# 1778 219_2b2_Ar_mc_LittC2SE.wav
# 1779 219_2b2_Tc_mc_LittC2SE.txt
# 1780 219_2b2_Tc_mc_LittC2SE.wav
# 1781 219_2b3_Tc_mc_LittC2SE.txt
# 1782 219_2b3_Tc_mc_LittC2SE.wav
# 1783 220_1b1_Tc_mc_LittC2SE.txt
# 1784 220_1b1_Tc_mc_LittC2SE.wav
# 1785 220_1b2_Al_mc_LittC2SE.txt
# 1786 220_1b2_Al_mc_LittC2SE.wav
# 1787 221_2b1_Al_mc_LittC2SE.txt
# 1788 221_2b1_Al_mc_LittC2SE.wav
# 1789 221_2b1_Ar_mc_LittC2SE.txt
# 1790 221_2b1_Ar_mc_LittC2SE.wav
# 1791 221_2b1_Lr_mc_LittC2SE.txt
# 1792 221_2b1_Lr_mc_LittC2SE.wav
# 1793 221_2b1_Pl_mc_LittC2SE.txt
# 1794 221_2b1_Pl_mc_LittC2SE.wav
# 1795 221_2b2_Al_mc_LittC2SE.txt
# 1796 221_2b2_Al_mc_LittC2SE.wav
# 1797 221_2b2_Ar_mc_LittC2SE.txt
# 1798 221_2b2_Ar_mc_LittC2SE.wav
# 1799 221_2b2_Lr_mc_LittC2SE.txt
# 1800 221_2b2_Lr_mc_LittC2SE.wav
# 1801 221_2b2_Pl_mc_LittC2SE.txt
# 1802 221_2b2_Pl_mc_LittC2SE.wav
# 1803 221_2b3_Al_mc_LittC2SE.txt
# 1804 221_2b3_Al_mc_LittC2SE.wav
# 1805 221_2b3_Ar_mc_LittC2SE.txt
# 1806 221_2b3_Ar_mc_LittC2SE.wav
# 1807 221_2b3_Lr_mc_LittC2SE.txt
# 1808 221_2b3_Lr_mc_LittC2SE.wav
# 1809 221_2b3_Pr_mc_LittC2SE.txt
# 1810 221_2b3_Pr_mc_LittC2SE.wav
# 1811 222_1b1_Ar_sc_Meditron.txt
# 1812 222_1b1_Ar_sc_Meditron.wav
# 1813 222_1b1_Lr_sc_Meditron.txt
# 1814 222_1b1_Lr_sc_Meditron.wav
# 1815 222_1b1_Pr_sc_Meditron.txt
# 1816 222_1b1_Pr_sc_Meditron.wav
# 1817 223_1b1_Al_sc_Meditron.txt
# 1818 223_1b1_Al_sc_Meditron.wav
# 1819 223_1b1_Ar_sc_Meditron.txt
# 1820 223_1b1_Ar_sc_Meditron.wav
# 1821 223_1b1_Ll_sc_Meditron.txt
# 1822 223_1b1_Ll_sc_Meditron.wav
# 1823 223_1b1_Lr_sc_Meditron.txt
# 1824 223_1b1_Lr_sc_Meditron.wav
# 1825 223_1b1_Pl_sc_Meditron.txt
# 1826 223_1b1_Pl_sc_Meditron.wav
# 1827 223_1b1_Pr_sc_Meditron.txt
# 1828 223_1b1_Pr_sc_Meditron.wav
# 1829 224_1b1_Tc_sc_Meditron.txt
# 1830 224_1b1_Tc_sc_Meditron.wav
# 1831 224_1b2_Al_sc_Meditron.txt
# 1832 224_1b2_Al_sc_Meditron.wav
# 1833 225_1b1_Pl_sc_Meditron.txt
# 1834 225_1b1_Pl_sc_Meditron.wav
# 1835 226_1b1_Al_sc_Meditron.txt
# 1836 226_1b1_Al_sc_Meditron.wav
# 1837 226_1b1_Ll_sc_Meditron.txt
# 1838 226_1b1_Ll_sc_Meditron.wav
# 1839 226_1b1_Pl_sc_LittC2SE.txt
# 1840 226_1b1_Pl_sc_LittC2SE.wav

# %%
# another WAY
dirpath=next(os.walk(path))[0]
subdirectories=next(os.walk(path))[1]
filenames=next(os.walk(path))[2]

# %% [markdown]
# **Waht root actually Returns you. It go to the file path and yields a 3-tuple (iterator).
# The basic difference between Iterator and ListIterator is that both being cursor, Iterator can traverse elements in a collection only in forward direction and One Iteration at a Time. On the other hand, the ListIterator can traverse in both forward and backward directions. Returns**
# * Path we passed
# * SubDirectories
# * Files in that Path

# %%
### Iterartors
a=iter(['C','Java','Python'])

# %%
next(a,"End of Iterartot")
# Out:
# 'C'

# %%
next(a,"End of Iterartot")
# Out:
# 'Java'

# %%
next(a,"End of Iterartot")
# Out:
# 'Python'

# %%
next(a,"End of Iterartot")
# Out:
# 'End of Iterartot'

# %% [markdown]
# ## Generators
# **A Function is called generator if it Yeild an iterator.To convert a function into Genrator
# we need to use Yeild except Return. RETURN TERMINATE THE FUNCTION YEILD WILL NOT**

# %%
def give_num():
    yield 5
value=give_num()
print(value) # It will give you Iterartor Object
print(next(value))
# Out:
# <generator object give_num at 0x00000221F8649A20>
# 5

# %%
def sum_list(data):
    num=[]
    for pos,i in enumerate(data):
        num.append(i*pos)
    return num

sum_list([1,2,3])
# Out:
# [0, 2, 6]

# %%
def sum_nums(data): # yeild doesn't suspend the function 
    num=[]
    for i in data:
        num = num+i
        yield num

# %% [markdown]
# ## OOP

# %%
class Myclass1:
    x=5
obj=Myclass1()
obj.x
# Out:
# 5

# %%
class employe:
    def __init__(self,name='Noname',age=0): # Constructors, With default Parameteres
        self.name=name
        self.age=age
    def myfunc(self):                       # object method
        print("Hello my name is " + self.name)
    
obj=employe("Abdul",25)
obj.name
obj.age=24                     # Changing object properties  
obj.myfunc()

class Person:              # Empty class 
      pass
# Out:
# Hello my name is Abdul

# %%
class admin(employe):
    def __init__(self):
        super().__init__()
    def name(self):
        print(self.name)

# %%
obb=employe("aaa")

# %%
a=admin()

# %%
obb.name
# Out:
# 'aaa'
