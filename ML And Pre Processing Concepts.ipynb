# %% [markdown]
# ### Model Performance

# %% [markdown]
# ### In Our track to train a model for Predictions
# #### our main Goal is to Avoid  Over Fitting And Under Fitting of a Model

# %% [markdown]
#  #### Why to Avoid
#  * Avoid Underfitting to Make our Model Accurate
#  * Avoid Overfitting to make our model Consistent

# %% [markdown]
# **Errors in ML is Because of two main reason**
# * Because of Bias
# * Becaus of Variance

# %% [markdown]
# ### What is Bias...?

# %% [markdown]
# **Expected error in the predicted value due to the assumptions we made while training of Model**
# e.g in regression we fit the Regressor to the Data assuming Target has the linear Relation with the dependent variables

# %% [markdown]
# ### High Bias Means Model is Underfitting

# %% [markdown]
# ### Bias is Normally Defined as Expectaion
# ###### E[Y'-Y]
# * Y' - Predicted Value
# * Y - Value to be Predicted

# %% [markdown]
# ## What is Variance....?
# **Variance is the Predicted Values when we change the Dataset**

# %% [markdown]
# #### High Variance means Model is Overfitted

# %% [markdown]
# ## Variance and Bias Both are Inversely Propotional

# %% [markdown]
# ### Decrease in Bias will increase Variance and vice versa
# ##### This is Bias Variance Trade Off

# %% [markdown]
# #### Our target is Lowst biased with  Lowest Variance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### How to achive Optimal Balance among the Bias and Variance

# %% [markdown]
# ### Through
# * Dimentionality Reduction
# * Tuning Model for Best Parameteres
# * Ragularization in Lieanar Models and Artficial Neural Networks
# * Using Mixture Models and Ensemble Learning

# %% [markdown]
# **Ensembling**
# In statistics and machine learning, ensemble methods use multiple learning algorithms to obtain better predictive performance than could be obtained from any of the constituent learning algorithms alone.
# ![image.png](attachment:image.png)

# %% [markdown]
# **Regularization**
# That's the set of parameters. In short, Regularization in machine learning is the process of regularizing the parameters that constrain, regularizes, or shrinks the coefficient estimates towards zero. In other words, this technique discourages learning a more complex or flexible model, avoiding the risk of Overfitting

# %% [markdown]
# Regularization is a technique which makes slight modifications to the learning algorithm such that the model generalizes better. This in turn improves the model's performance on the unseen data as well

# %% [markdown]
# # Feature Scalling
# **Why do we need to scale the variables in our dataset?** .
# If feature scaling is not done, then a machine learning algorithm tends to weigh greater values, higher and consider smaller values as the lower values, regardless of the unit of the values.
#
# ###### Gradient Descent Based Algorithms
#  Machine learning algorithms like linear regression, logistic regression, neural network etc. that use gradient descent as an optimization technique require data to be scaled.
# **Having features on a similar scale can help the gradient descent converge more quickly towards the minima**
#
# ##### Distance-Based Algorithms
# Distance algorithms like KNN, K-means, and SVM are most affected by the range of features. This is because behind the scenes they are using distances between data points to determine their similarity.
# **Therefore, we scale our data before employing a distance based algorithm so that all the features contribute equally to the result**
# > These Algorithams are Sensitive to Feature Scaling While Tree-Based are Not

# %% [markdown]
# ### (Gradient Descent)
# **Gradient descent is an optimization algorithm used to find the values of parameters (coefficients) of a function (f) that minimizes a cost function (cost... which simply the error between predicted and actual values) OR**
# ". A gradient measures how much the output of a function changes if you change the inputs a little bit." — Lex Fridman (MIT). In mathematical terms, a gradient is a partial derivative with respect to its inputs.How big the steps are gradient descent takes into the direction of the local minimum are determined by the learning rate.For gradient descent to reach the local minimum we must set the learning rate to an appropriate value, which is neither too low nor too high.
# A good way to make sure gradient descent runs properly is by plotting the cost function as the optimization runs. Put the number of iterations on the x-axis and the value of the cost-function on the y-axis.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Cost Function.
# A cost function is a mechanism utilized in supervised machine learning, the cost function returns the error between predicted outcomes compared with the actual outcomes.
# **Mathematically, the technique of the 'derivative' is extremely important to minimise the cost function because it helps get the minimum point (Global minima). The derivative is a concept from calculus and refers to the slope of the function at a given point**

# %% [markdown]
# # Techniques to perform Feature Scaling
# Consider the two most important ones:

# %% [markdown]
# ### Min-Max Normalization:
# **This technique re-scales a feature or observation value with distribution value between 0 and 1**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Standardization:
# **Uses Staard deviation. It is a very effective technique which re-scales a feature value so that it has distribution with 0 mean value and variance equals to 1**
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Normalization vs Standardization
# Normalization is to scale values between 0 and 1, Standardization is about having Mean as 0 and Standard Deviation as 1. There are some points to be considered while deciding whether we need Standardization or Normalization
#
# * Standardization can be used in case when data represent Gaussian Curve
# * Standardization is less impacted by outlier values.
# * Impact of Outliers is very high in Normalization
# * Normalization is great when Non Gaussian Curve Representation.
#
# **Gaussian distribution** also known as the Normal distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a bell curve.

# %% [markdown]
# ## Treating Null Values

# %% [markdown]
# ## Treating Catagorical Values

# %% [markdown]
# ## Outliers Treatment

# %% [markdown]
# # Feature Selection.
# Selecting relevent features.Discarding Irrelevent features for example for Predicting milage of a car COLOUR is a irrelevent feature.

# %% [markdown]
# # Feature Extration.
# Feature Extraction aims to reduce the number of features in a dataset by creating new features from the existing ones (and then discarding the original features) without losing necessary information.Encoding Catagorical variables , extracting relevent info from textual, datetime feature.

# %% [markdown]
# # Regularization

# %% [markdown]
# # Dimenstionlity Reduction
# * Principal Componenet Analysis
# * Singular Value Decomposition

# %% [markdown]
# # Learn maths of few algorithams
