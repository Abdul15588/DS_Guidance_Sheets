# %% [markdown]
# ### DataFrames

# %%
import  pandas as pd
df1=pd.read_csv('Iris.csv')
df2=pd.DataFrame({"Id":[22,33,44,55,66 ],"Names":['Robert','Jhon','Caley','Albert','kameron'],"Sal":[34.4,23.5,57.6,76.8,88.4]},
            )

# %%
df2.to_excel("PD2.xlsx",index=False)

# %%
import numpy as np
df2['Sal']=pd.DataFrame(map(lambda x:x+10 , df2['Sal'])) #Map On df

# %%
df3=pd.DataFrame(np.random.rand(3,3),index=["Pahli","Dosri","Tessri"],columns=["Col1","Col2","Col3"])

# %%
df3.shape[0]
# Out:
# 3

# %%
df3.index=pd.date_range('10/10/1999',periods=df3.shape[0])

# %%
df3['Dates']=pd.date_range('10/10/1999',periods=df3.shape[0])

# %% [markdown]
# ### Properties Functions

# %%
df1.dtypes
df2.describe()
df1.info()
df1.values # array all the values
np.count_nonzero(df2)
df1['Species'].value_counts()
df1['Species'].unique()
df1.count()
df1.isnull()
df1.columns
df1['PetalLengthCm'].argmax()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### Selection

# %%
df1[['Id','Species']]
df1['Species'][2] 
df1['Id'].loc[10]
# Out:
# 11

# %%
df2.iloc[0][2]
# Out:
# 44.4

# %% [markdown]
# ### CLEANING

# %%
df3.columns=['Col1', 'Col2', 'Col3', 'Dates']
df1=pd.read_csv('titanic_train.csv')
(df1['Cabin'].isnull()).value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
nulls=df1[(df1['Cabin'].isnull())==True]

# %%
len(nulls)
# Out:
# 687

# %%
df1.dropna(axis=0,how='all',inplace=True,)

# %%
from scipy import stats
df1.describe(include='all')
df1.dropna(axis=1,thresh=100) # drop columns having

# %%
df1.fillna( df1['Age'].mean())

# %%
df1['Ticket'].astype(float)

# %%
df1['Ticket'].replace(str,0.0)

# %%
df1.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df1.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df1['Age'].std()
# Out:
# 14.526497332334044

# %%
df1['Age'].max()
df1['Age'].min()
# Out:
# 0.42

# %%
df1['Age'].dropna(inplace=True)

# %%
df1['Age'][(df1['Age']>(20))  & (df1['Age']<float(50))]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 8      27.0
# 13     39.0
# 18     31.0
# 20     35.0
# 21     34.0
# 23     28.0
# 25     38.0
# 30     40.0
# 34     28.0
# 35     42.0
# 37     21.0
# 40     40.0
# 41     27.0
# 51     21.0
# 52     49.0
# 53     29.0
# 56     21.0
# 57     28.5
# 60     22.0
# 61     38.0
# 62     45.0
# 66     29.0
# 69     26.0
# 70     32.0
# 72     21.0
#        ...
# 838    32.0
# 842    30.0
# 843    34.5
# 845    42.0
# 847    35.0
# 848    28.0
# 854    44.0
# 856    45.0
# 858    24.0
# 860    41.0
# 861    21.0
# 862    48.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 461, dtype: float64

# %%
df1.groupby(['Cabin','Sex']).sum()
# Out:
#               PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare
# Cabin Sex
# A10   male            584         0       1   36.0      0      0   40.1250
# A14   male            476         0       1    0.0      0      0   52.0000
# A16   female          557         1       1   48.0      1      0   39.6000
# A19   male            285         0       1    0.0      0      0   26.0000
# A20   male            600         1       1   49.0      1      0   56.9292
# A23   male            631         1       1   80.0      0      0   30.0000
# A24   male            868         0       1   31.0      0      0   50.4958
# A26   male            648         1       1   56.0      0      0   35.5000
# A31   male            210         1       1   40.0      0      0   31.0000
# A32   male            186         0       1    0.0      0      0   50.0000
# A34   male            446         1       1    4.0      0      2   81.8583
# ...

# %%
df1['Sex'][df1['Cabin']=='F4']
# Out:
# 183      male
# 618    female
# Name: Sex, dtype: object

# %%
df1[['Age','Pclass']].apply(np.max,axis=0)
# Out:
# Age       80.0
# Pclass     3.0
# dtype: float64
